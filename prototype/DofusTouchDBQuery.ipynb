# %%
import json
import requests
import asyncio
import aiohttp
import itertools

# %%
default_headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:126.0) Gecko/20100101 Firefox/126.0'
}

async def query_page(session, page, headers=default_headers):
    async with session.get(page, headers=headers) as response:
        return await response.text()
    
async def query_all_pages(pages, headers=default_headers):
    queries = []
    async with aiohttp.ClientSession() as session:
        queries = await asyncio.gather(*[query_page(session, page, headers) for page in pages], return_exceptions=True)
    return [q for q in queries]

# %%
req = requests.get('https://touch.dofusbook.net/items/touch/search/equipment?page=1')
first_page = json.loads(req.text)
pages = [first_page]
page_count = first_page["pages"]

query_res = await query_all_pages([f'https://touch.dofusbook.net/items/touch/search/equipment?page={i}' for i in range(1, page_count+1)])
pages.extend([json.loads(res) for res in query_res])

items = list(itertools.chain.from_iterable([p["data"] for p in pages]))

# %%
with open('item_db.json', 'w') as f:
    json.dump(items, f)

# %%
import pandas as pd
items = pd.DataFrame(items)
items
# Out:
#         id  official  picture  level  cloth_id  choose_effect  give_boost  \
# 0     5190     16382   171114    200       NaN              0           0
# 1     5189     16534   171194    200       NaN              0           0
# 2     5188     16186   171024    200       NaN              0           0
# 3     5187     16190   171025    200       NaN              0           0
# 4     5186     16354   171101    200       NaN              0           0
# ...    ...       ...      ...    ...       ...            ...         ...
# 2386  1406     11812     9206      1       NaN              0           0
# 2387  1199     10906    82056      1       NaN              0           0
# 2388   117       789    10009      1       NaN              0           0
# 2389  1142     10414    16251      1       NaN              0           0
# 2390  1059      9471    16231      1       NaN              0           0
#
#       cannot_fm  category_id subcategory_id  ... png_color1 png_color2  \
# 0             0           12           None  ...       None       None
# 1             0           16           None  ...       None       None
# 2             0           19           None  ...       None       None
# 3             0           16           None  ...       None       None
# 4             0           15           None  ...       None       None
# ...         ...          ...            ...  ...        ...        ...
# 2386          0           13           None  ...       None       None
# 2387          0           14           None  ...       None       None
# 2388          0           15           None  ...       None       None
# 2389          0           16           None  ...       None       None
# 2390          0           16           None  ...       None       None
#
#      png_color3 size cameleon                              slug  \
# 0          None  NaN      NaN         5190-amulette-de-shokkoth
# 1          None  NaN      NaN              5189-scaramouchapeau
# 2          None  NaN      NaN          5188-chaussons-de-macrab
# 3          None  NaN      NaN         5187-masque-de-funespadon
# 4          None  NaN      NaN                   5186-protopagne
# ...         ...  ...      ...                               ...
# 2386       None  NaN      NaN                    1406-elianneau
# 2387       None  NaN      0.0          1199-bouclier-draconique
# 2388       None  NaN      NaN            117-ceinture-du-kobeer
# 2389       None  NaN      0.0       1142-couronne-koninginnedag
# 2390       None  NaN      0.0  1059-chapeau-de-la-sain-ballotin
#
#                                                 effects  \
# 0     [{'item_id': 5190, 'id': 130, 'name': 'vi', 't...
# 1     [{'item_id': 5189, 'id': 330, 'name': 'ii', 't...
# 2     [{'item_id': 5188, 'id': 130, 'name': 'vi', 't...
# 3     [{'item_id': 5187, 'id': 130, 'name': 'vi', 't...
# 4     [{'item_id': 5186, 'id': 130, 'name': 'vi', 't...
# ...                                                 ...
# 2386  [{'item_id': 1406, 'id': 700, 'name': 'ti', 't...
# 2387  [{'item_id': 1199, 'id': 620, 'name': 'pap', '...
# 2388  [{'item_id': 117, 'id': 140, 'name': 'fo', 'ty...
# 2389  [{'item_id': 1142, 'id': 200, 'name': 'cc', 't...
# 2390  [{'item_id': 1059, 'id': 200, 'name': 'cc', 't...
#
#                                             constraints  \
# 0                                                    []
# 1     [[{'item_id': 5189, 'id': 50, 'name': 'pa', 's...
# 2     [[{'item_id': 5188, 'id': 50, 'name': 'pa', 's...
# 3     [[{'item_id': 5187, 'id': 50, 'name': 'pa', 's...
# 4     [[{'item_id': 5186, 'id': 50, 'name': 'pa', 's...
# ...                                                 ...
# 2386                                                 []
# 2387                                                 []
# 2388                                                 []
# 2389                                                 []
# 2390                                                 []
#
#                                             ingredients weapon
# 0     [{'item_id': 5190, 'id': 11883, 'name': 'Condy...   None
# 1     [{'item_id': 5189, 'id': 11522, 'name': 'Fragm...   None
# 2     [{'item_id': 5188, 'id': 8809, 'name': 'Culott...   None
# 3     [{'item_id': 5187, 'id': 11527, 'name': 'Peau ...   None
# 4     [{'item_id': 5186, 'id': 8808, 'name': 'Étoffe...   None
# ...                                                 ...    ...
# 2386                                                 []   None
# 2387                                                 []   None
# 2388                                                 []   None
# 2389                                                 []   None
# 2390                                                 []   None
#
# [2391 rows x 31 columns]

# %%
touch_domain = "https://www.dofus-touch.com"

# %%
from bs4 import BeautifulSoup
import re

professions = {}
profession_pages = await query_all_pages(f'https://www.dofus-touch.com/fr/mmorpg/encyclopedie/metiers?display=table&page={i+1}' for i in [0, 1])
for profession_page in profession_pages[0:1]:
    soup = BeautifulSoup(profession_page, 'html.parser')

    # The page is composed of a list of professions. First get the panel where they are located
    main_panel = soup.find("div", "ak-container ak-main-center")

    # The look for each item
    profession_items = main_panel.find_all("td", "item-name")
    assert(len(profession_items) > 0)

    for profession_item in profession_items:
        # The profession item is composed of the "item-name" containing the name in the string and a child "a" link
        professions[profession_item.string.strip()] = {"link":profession_item.find("a", href=re.compile("encyclopedie/metiers/")).get("href")}

# %%
professions
# Out:
# {'Alchimiste': {'link': '/fr/mmorpg/encyclopedie/metiers/26-alchimiste'},
#  'Bijoutier': {'link': '/fr/mmorpg/encyclopedie/metiers/16-bijoutier'},
#  'Boucher': {'link': '/fr/mmorpg/encyclopedie/metiers/56-boucher'},
#  'Boulanger': {'link': '/fr/mmorpg/encyclopedie/metiers/25-boulanger'},
#  'Bricoleur': {'link': '/fr/mmorpg/encyclopedie/metiers/65-bricoleur'},
#  'Bûcheron': {'link': '/fr/mmorpg/encyclopedie/metiers/2-bucheron'},
#  'Chasseur': {'link': '/fr/mmorpg/encyclopedie/metiers/41-chasseur'},
#  'Cordomage': {'link': '/fr/mmorpg/encyclopedie/metiers/62-cordomage'},
#  'Cordonnier': {'link': '/fr/mmorpg/encyclopedie/metiers/15-cordonnier'},
#  'Costumage': {'link': '/fr/mmorpg/encyclopedie/metiers/64-costumage'},
#  'Façonneur': {'link': '/fr/mmorpg/encyclopedie/metiers/60-faconneur'},
#  "Forgemage d'Epées": {'link': '/fr/mmorpg/encyclopedie/metiers/44-forgemage-epees'},
#  'Forgemage de Dagues': {'link': '/fr/mmorpg/encyclopedie/metiers/43-forgemage-dagues'},
#  'Forgemage de Haches': {'link': '/fr/mmorpg/encyclopedie/metiers/47-forgemage-haches'},
#  'Forgemage de Marteaux': {'link': '/fr/mmorpg/encyclopedie/metiers/45-forgemage-marteaux'},
#  'Forgemage de Pelles': {'link': '/fr/mmorpg/encyclopedie/metiers/46-forgemage-pelles'},
#  "Forgeur d'Epées": {'link': '/fr/mmorpg/encyclopedie/metiers/11-forgeur-epees'},
#  'Forgeur de Dagues': {'link': '/fr/mmorpg/encyclopedie/metiers/17-forgeur-dagues'},
#  'Forgeur de Haches': {'link': '/fr/mmorpg/encyclopedie/metiers/31-forgeur-haches'},
#  'Forgeur de Marteaux': {'link': '/fr/mmorpg/encyclopedie/metiers/14-forgeur-marteaux'},
#  'Forgeur de Pelles': {'link': '/fr/mmorpg/encyclopedie/metiers/20-forgeur-pelles'},
#  'Joaillomage': {'link': '/fr/mmorpg/encyclopedie/metiers/63-joaillomage'},
#  'Mineur': {'link': '/fr/mmorpg/encyclopedie/metiers/24-mineur'},
#  'Paysan': {'link': '/fr/mmorpg/encyclopedie/metiers/28-paysan'}}

# %%
profession_pages
# Out:
# ['<!DOCTYPE HTML>\n<html xmlns="http://www.w3.org/1999/xhtml" lang="fr" xml:lang="fr">\n<head>\n  <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n  <title>Métiers - Encyclopédie DOFUS -  DOFUS Touch, le MMORPG ultime sur mobile</title>\n  <meta name="description" content="Maîtrisez jusqu\'à trois métiers simultanément parmi les vingt-deux existants ! En combinant récolte et artisanat, vous créerez vos propres objets et équipements." />\n  <meta name="keywords" content="ARTISANAT, METIERS,  COLLECTE, FORGEMAGIE, ALCHIMISTE, BUCHERON, MINEUR, PAYSAN, PECHEUR, BIJOUTIER, BOUCHER, BOULANGER, BRICOLEUR, CHASSEUR, CORDONNIER, FORGEUR, POISSONNIER, SCULPTEUR, TAILLEUR, DOFUS, ENCYCLOPEDIE, MMORPG, JEU EN LIGNE" />\n  <meta name="Identifier-URL" content="www.dofus-touch.com" />\n  <meta name="language" content="fr" />\n  <meta http-equiv="imagetoolbar" content="no" />\n  <meta property="fb:admins" content="100000245210540"/>\n  <meta property="og:type" content="website"/>\n  <meta property="og:locale" content="fr_FR"/>\n  <meta property="og:title" content="Métiers - Encyclopédie DOFUS -  DOFUS Touch, le MMORPG ultime sur mobile"/>\n  <meta property="og:description" content="Maîtrisez jusqu\'à trois métiers simultanément parmi les vingt-deux existants ! En combinant récolte et artisanat, vous créerez vos propres objets et équipements." />\n  <meta property="og:url" content="https://www.dofus-touch.com/fr/mmorpg/encyclopedie/metiers?display=table&amp;page=1" />\n  <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" />\n  <meta name="format-detection" content="telephone=no" />\n  <meta name="facebook-domain-verification" content="8737irodwyp95zxcu9227e56gziicm" />\n  <meta name="twitter:card" content="summary" />\n  <meta name="twitter:site" content="@ankamagames" />\n  <meta name="twitter:creator" content="@ankamagames" />\n  <meta name="robots" content="NOODP,Index,Follow" />\n  <link type="image/x-icon" rel="shortcut icon" href="/favicon.ico" />\n  <link rel="dns-prefetch" href="static.ankama.com" />\n  <link rel="image_src" href="https://static.ankama.com/dofus-touch/www/img/logo.jpg" />\n  <meta property="og:image" content="https://static.ankama.com/dofus-touch/www/img/logo.jpg" />\n  <link rel="alternate" href="https://www.dofus-touch.com/en/mmorpg/encyclopedia/professions?display=table&amp;page=1" hreflang="en" />\n  <link rel="alternate" href="https://www.dofus-touch.com/es/mmorpg/enciclopedia/oficios?display=table&amp;page=1" hreflang="es" />\n  <link type="application/rss+xml" rel="alternate" href="/fr/rss/news.xml" title="News" />\n  <link type="application/rss+xml" rel="alternate" href="/fr/rss/changelog.xml" title="Changelog" />\n  <link type="application/rss+xml" rel="alternate" href="/fr/rss/devblog.xml" title="Devblog" />\n  <link type="text/css" rel="stylesheet" href="https://static.ankama.com/dofus-touch/www/css/../modules/common/common.css" />\n  <link type="text/css" rel="stylesheet" href="https://static.ankama.com/dofus-touch/www/css/../modules/mmorpg/community/community.css" />\n  <link type="text/css" rel="stylesheet" href="https://static.ankama.com/dofus-touch/www/css/../modules/mmorpg/encyclopedia/encyclopedia.css" />\n  <link rel="next" href="/fr/mmorpg/encyclopedie/metiers?display=table&amp;page=2" />\n  <script type="text/javascript">\n    AUTH_LOGIN_URL = "https:\\/\\/account.ankama.com\\/webauth\\/authorize?from=https:\\/\\/www.dofus-touch.com\\/fr\\/mmorpg\\/encyclopedie\\/metiers?display=table&page=1";\n  </script>\n  <script type="text/javascript">\n    var _gaq = _gaq || [];\n  </script>\n<style id="clickjakingPreventionScript">\n                body{\n                    display:none !important;\n                }\n            </style>\n            <script>\n                  if (self === top) {\n                        let antiClickjack = document.getElementById("clickjakingPreventionScript");\n                        antiClickja ...
#  '<!DOCTYPE HTML>\n<html xmlns="http://www.w3.org/1999/xhtml" lang="fr" xml:lang="fr">\n<head>\n  <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n  <title>Métiers - Encyclopédie DOFUS -  DOFUS Touch, le MMORPG ultime sur mobile</title>\n  <meta name="description" content="Maîtrisez jusqu\'à trois métiers simultanément parmi les vingt-deux existants ! En combinant récolte et artisanat, vous créerez vos propres objets et équipements." />\n  <meta name="keywords" content="ARTISANAT, METIERS,  COLLECTE, FORGEMAGIE, ALCHIMISTE, BUCHERON, MINEUR, PAYSAN, PECHEUR, BIJOUTIER, BOUCHER, BOULANGER, BRICOLEUR, CHASSEUR, CORDONNIER, FORGEUR, POISSONNIER, SCULPTEUR, TAILLEUR, DOFUS, ENCYCLOPEDIE, MMORPG, JEU EN LIGNE" />\n  <meta name="Identifier-URL" content="www.dofus-touch.com" />\n  <meta name="language" content="fr" />\n  <meta http-equiv="imagetoolbar" content="no" />\n  <meta property="fb:admins" content="100000245210540"/>\n  <meta property="og:type" content="website"/>\n  <meta property="og:locale" content="fr_FR"/>\n  <meta property="og:title" content="Métiers - Encyclopédie DOFUS -  DOFUS Touch, le MMORPG ultime sur mobile"/>\n  <meta property="og:description" content="Maîtrisez jusqu\'à trois métiers simultanément parmi les vingt-deux existants ! En combinant récolte et artisanat, vous créerez vos propres objets et équipements." />\n  <meta property="og:url" content="https://www.dofus-touch.com/fr/mmorpg/encyclopedie/metiers?display=table&amp;page=2" />\n  <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" />\n  <meta name="format-detection" content="telephone=no" />\n  <meta name="facebook-domain-verification" content="8737irodwyp95zxcu9227e56gziicm" />\n  <meta name="twitter:card" content="summary" />\n  <meta name="twitter:site" content="@ankamagames" />\n  <meta name="twitter:creator" content="@ankamagames" />\n  <meta name="robots" content="NOODP,Index,Follow" />\n  <link type="image/x-icon" rel="shortcut icon" href="/favicon.ico" />\n  <link rel="dns-prefetch" href="static.ankama.com" />\n  <link rel="image_src" href="https://static.ankama.com/dofus-touch/www/img/logo.jpg" />\n  <meta property="og:image" content="https://static.ankama.com/dofus-touch/www/img/logo.jpg" />\n  <link rel="alternate" href="https://www.dofus-touch.com/en/mmorpg/encyclopedia/professions?display=table&amp;page=2" hreflang="en" />\n  <link rel="alternate" href="https://www.dofus-touch.com/es/mmorpg/enciclopedia/oficios?display=table&amp;page=2" hreflang="es" />\n  <link type="application/rss+xml" rel="alternate" href="/fr/rss/news.xml" title="News" />\n  <link type="application/rss+xml" rel="alternate" href="/fr/rss/changelog.xml" title="Changelog" />\n  <link type="application/rss+xml" rel="alternate" href="/fr/rss/devblog.xml" title="Devblog" />\n  <link type="text/css" rel="stylesheet" href="https://static.ankama.com/dofus-touch/www/css/../modules/common/common.css" />\n  <link type="text/css" rel="stylesheet" href="https://static.ankama.com/dofus-touch/www/css/../modules/mmorpg/community/community.css" />\n  <link type="text/css" rel="stylesheet" href="https://static.ankama.com/dofus-touch/www/css/../modules/mmorpg/encyclopedia/encyclopedia.css" />\n  <link rel="prev" href="/fr/mmorpg/encyclopedie/metiers?display=table&amp;page=1" />\n  <script type="text/javascript">\n    AUTH_LOGIN_URL = "https:\\/\\/account.ankama.com\\/webauth\\/authorize?from=https:\\/\\/www.dofus-touch.com\\/fr\\/mmorpg\\/encyclopedie\\/metiers?display=table&page=2";\n  </script>\n  <script type="text/javascript">\n    var _gaq = _gaq || [];\n  </script>\n<style id="clickjakingPreventionScript">\n                body{\n                    display:none !important;\n                }\n            </style>\n            <script>\n                  if (self === top) {\n                        let antiClickjack = document.getElementById("clickjakingPreventionScript");\n                        antiClickja ...

# %%
profession_pages = await query_all_pages([l for l in [touch_domain + l["link"] + "/recipes" for l in professions.values()]])

all_recipes = []
for [[profession_name, profession], profession_first_page] in zip(professions.items(), profession_pages): 
    page_id = 1
    page = profession_first_page
    profession["recipes"] = []
    while (page != None):
        profession_page = BeautifulSoup(page, 'html.parser')

        # There should be a tab content panel containing tabs for harvests and recipes
        tab_panel = profession_page.find("div", "tab-content") 

        # Get the currently active tab, which should be the recipes. Inactive tabs will have the "ak-tab hide" class
        recipe_tabs = [f for f in tab_panel.find_all("div", "ak-tab") if "hide" not in f["class"]]
        
        # We only expect magus items to be without a tab
        if (len(recipe_tabs) == 0):
            assert("mage" in profession_name)
            page = None
            continue

        # Go the the tab body
        tab_body = recipe_tabs[0].find("tbody")

        # This body should have a list of "tr" elements with the recipe dynamically loadable
        recipes_tr = tab_body.find_all("tr", attrs={"ajax-details-url":re.compile("objets/recette/")})
        
        for recipe_tr in recipes_tr:
            recipe = {}

            # The recipe contains a link to the crafted resource
            link_html  = recipe_tr.find("a", href=re.compile("encyclopedie/"))

            # Row contains the name of the object, then the level. link_html is the child of the name container, which is sibling of the level's container
            level_html = link_html.parent.findNextSibling("td")

            # The detail url is of form "/en/mmorpg/encyclopedia/items/recipe/286", 286 being the item id
            recipe["detail_url"]    = recipe_tr.get("ajax-details-url")
            recipe["object_id"]     = int(recipe["detail_url"].split("/")[-1])
            recipe["object_name"]   = link_html.string
            recipe["link"]          = link_html.get("href")
            recipe["level"]         = int(level_html.string)
            recipe["profession"]    = profession_name

            all_recipes.append(recipe)
            profession["recipes"].append(recipe)

        page_id += 1
        page = None
        next_page_link = profession_page.find("link", rel="next", href=re.compile(profession["link"]))
        if next_page_link != None:
            page = requests.get(touch_domain + next_page_link.get("href"), headers=default_headers).text

# %%
profession_page
# Out:
# <!DOCTYPE HTML>
#
# <html lang="fr" xml:lang="fr" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <title>Paysan - Métiers - Encyclopédie DOFUS -  DOFUS Touch, le MMORPG ultime sur mobile</title>
# <meta content="Le paysan consacre une partie de son temps à faucher des céréales dans les champs de la province d'Amakna, et l'autre partie à moudre le fruit de ses récoltes pour vendre ses farines aux boulangers les plus offrants." name="description"/>
# <meta content="PAYSAN, METIERS, ARTISANAT, RECOLTES, RESSOURCES, RECETTES, DOFUS, ENCYCLOPEDIE, MMORPG, JEU EN LIGNE" name="keywords"/>
# <meta content="www.dofus-touch.com" name="Identifier-URL"/>
# <meta content="fr" name="language"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <meta content="100000245210540" property="fb:admins"/>
# <meta content="website" property="og:type"/>
# <meta content="fr_FR" property="og:locale"/>
# <meta content="Paysan - Métiers - Encyclopédie DOFUS -  DOFUS Touch, le MMORPG ultime sur mobile" property="og:title"/>
# <meta content="Le paysan consacre une partie de son temps à faucher des céréales dans les champs de la province d'Amakna, et l'autre partie à moudre le fruit de ses récoltes pour vendre ses farines aux boulangers les plus offrants." property="og:description"/>
# <meta content="https://www.dofus-touch.com/fr/mmorpg/encyclopedie/metiers/28-paysan?page=2" property="og:url"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="8737irodwyp95zxcu9227e56gziicm" name="facebook-domain-verification"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@ankamagames" name="twitter:site"/>
# <meta content="@ankamagames" name="twitter:creator"/>
# <meta content="NOODP,Index,Follow" name="robots"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="static.ankama.com" rel="dns-prefetch"/>
# <link href="https://static.ankama.com/dofus-touch/www/img/logo.jpg" rel="image_src"/>
# <meta content="https://static.ankama.com/dofus-touch/www/img/logo.jpg" property="og:image"/>
# <link href="https://www.dofus-touch.com/en/mmorpg/encyclopedia/professions/28-paysan?page=2" hreflang="en" rel="alternate"/>
# <link href="https://www.dofus-touch.com/es/mmorpg/enciclopedia/oficios/28-paysan?page=2" hreflang="es" rel="alternate"/>
# <link href="/fr/rss/news.xml" rel="alternate" title="News" type="application/rss+xml"/>
# <link href="/fr/rss/changelog.xml" rel="alternate" title="Changelog" type="application/rss+xml"/>
# <link href="/fr/rss/devblog.xml" rel="alternate" title="Devblog" type="application/rss+xml"/>
# <link href="https://static.ankama.com/dofus-touch/www/css/../modules/common/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://static.ankama.com/dofus-touch/www/modules/mmorpg/encyclopedia/encyclopedia.css" rel="stylesheet" type="text/css"/>
# <link href="/fr/mmorpg/encyclopedie/metiers/28-paysan?page=1" rel="prev"/>
# <script type="text/javascript">
#     AUTH_LOGIN_URL = "https:\/\/account.ankama.com\/webauth\/authorize?from=https:\/\/www.dofus-touch.com\/fr\/mmorpg\/encyclopedie\/metiers\/28-paysan?page=2";
#   </script>
# <script type="text/javascript">
#     var _gaq = _gaq || [];
#   </script>
# <style id="clickjakingPreventionScript">
#                 body{
#                     display:none !important;
#                 }
#             </style>
# <script>
#                   if (self === top) {
#                         let antiClickjack = document.getElementById("clickjakingPreventionScript");
#                         antiClickjack.parentNode.removeChild(antiClickjack);
#                   } else {
#                     top.location = self.location;
#                   }
#             </script></head>
# <body class="fr">
# <!-- Le paysan consacre une partie de son temps à faucher des céréales dans les champs de la province d'Amakna, et l'autre partie à moudre le fruit de ses récoltes pour vendre ses farines aux boulangers les plus offrants. -->
# <div class="ak-lazyload-notifications" data-position="HEADER" style="display: none"></div>
# <header>
# <div class="ak-idbar">
# <div class="ak-idbar-content">
# <div class="ak-idbar-left">
# <div class="ak-brand" data-set="ak-brand"> <a class="navbar-brand" href="https://www.ankama.com" target="_blank"></a>
# </div>
# <a class="ak-support" href="https://support.ankama.com" target="_blank">Support</a>
# </div>
# <div class="ak-idbar-right">
# <div class="ak-nav-not-logged">
# <div class="ak-connect-links">
# <a class="login" href="https://account.ankama.com/webauth/authorize?from=https%3A%2F%2Fwww.dofus-touch.com%2Ffr%2Fmmorpg%2Fencyclopedie%2Fmetiers%2F28-paysan%3Fpage%3D2">
# <span>Connexion</span>
# <img alt="Avatar" class="img-responsive" src="https://static.ankama.com/web-avatar/0.png"/>
# </a>
# <!--a  href="http://www.dofus-touch.com/fr/mmorpg/jouer"  class="register">
#       Inscription    </a-->
# </div>
# </div><div class="ak-button-modal ak-flags-links">
# <a class="ak-flag" href="#"></a>
# </div>
# <div class="ak-idbar-box ak-box-lang">
# <a class="ak-flag-fr" href="/fr/mmorpg/encyclopedie/metiers/28-paysan?page=2" hreflang="fr">FR</a>
# <a class="ak-flag-en" href="/en/mmorpg/encyclopedia/professions/28-paysan?page=2" hreflang="en">EN</a>
# <a class="ak-flag-es" href="/es/mmorpg/enciclopedia/oficios/28-paysan?page=2" hreflang="es">ES</a>
# </div>
# </div>
# </div>
# </div>
# <nav class="navbar navbar-default" data-role="ak_navbar">
# <div class="navbar-container">
# <div class="ak-navbar-left">
# <a class="ak-brand" href="http://www.ankama-group.com">Ankama</a>
# </div>
# <a class="ak-main-logo" href="/fr"></a>
# <div class="navbar-header">
# <!-- <a href="#" class="ak-nav-search"></a> -->
# <!--<a id="nav-toggle" href="#"><span></span></a>-->
# <a class="burger-btn" href="javascript:void(0)"><span></span></a>
# </div>
# <div class="navbar-collapse navbar-ex1-collapse collapse">
# <div class="ak-navbar-search-mob">
# <div class="ak-form"><form action="/fr/recherche" class="ak-container" method="get" role="form">
# <div class="form-group">
# <input autocapitalize="off" autocorrect="off" class="form-control ak-autocomplete" name="q" type="text" value="Rechercher..."/><script type="application/json">{"minLength":1,"delay":0,"select":"location","url":"https:\/\/www.dofus-touch.com\/fr\/autocomplete","titlemax":45,"shownoresults":true,"noresults":"Voir tous les r\u00e9sultats"}</script>
# </div>
# <input class="" type="button" value="ok"/>
# </form></div> </div>
# <ul class="nav navbar-nav">
# <span class="ak-navbar-left-part">
# <li class="lvl0 dropdown sep">
# <a class="dropdown-toggle" data-toggle="dropdown" href="javascript:void(0);">L'univers <b class="caret"></b></a>
# <ul class="dropdown-menu dropdown-menu-left" role="menu">
# <li class="lvl1 nopointer">
# <a href="javascript:void(0);">Jeu en ligne</a>
# <ul>
# <li class="lvl2">
# <a href="/fr/mmorpg/decouvrir">Découvrir</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/tutoriels">Apprendre à jouer</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/telecharger">Télécharger le jeu</a>
# </li>
# </ul>
# </li>
# <li class="lvl1 col2 animation nopointer">
# <a href="javascript:void(0);">Animation</a>
# <ul>
# <li class="lvl2">
# <a href="/fr/animation/univers">La série</a>
# </li>
# <li class="lvl2">
# <a href="http://www.dofus-le-film.com/fr" target="_blank">Le film</a>
# </li>
# </ul>
# </li>
# <li class="lvl1 col3 editions nopointer">
# <a href="javascript:void(0);">Editions</a>
# <ul>
# <li class="lvl2">
# <a href="/fr/editions/univers">Découvrir</a>
# </li>
# </ul>
# </li>
# <li class="lvl1 col4 krosmaster nopointer">
# <a href="javascript:void(0);">DOFUS Krosmaster</a>
# <ul>
# <li class="lvl2">
# <a href="http://www.krosmaster.com/fr">Découvrir</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="lvl0 dropdown sep">
# <a class="dropdown-toggle" data-toggle="dropdown" href="javascript:void(0);">Actualités <b class="caret"></b></a>
# <ul class="dropdown-menu" role="menu">
# <li class="lvl1">
# <ul>
# <li class="lvl2">
# <a href="/fr/mmorpg/actualites/news">News</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/actualites/devblog">Devblog</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/actualites/maj">Mises à jour</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="lvl0 dropdown sep">
# <a class="dropdown-toggle" data-toggle="dropdown" href="javascript:void(0);">Encyclopédie <b class="caret"></b></a>
# <ul class="dropdown-menu" role="menu">
# <li class="lvl1">
# <ul>
# <li class="lvl2">
# <a href="/fr/mmorpg/encyclopedie/classes">Classes</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/encyclopedie/metiers">Métiers</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/encyclopedie/monstres">Bestiaire</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/encyclopedie/armes">Armes</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/encyclopedie/equipements">équipements</a>
# </li>
# <li class="lvl2">
# <a href="http://www.krosmoz.com/fr/almanax?game=dofustouch" target="_blank">Almanax</a>
# </li>
# </ul>
# </li>
# <li class="lvl1">
# <ul>
# <li class="lvl2">
# <a href="/fr/mmorpg/encyclopedie/panoplies">Panoplies</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/encyclopedie/familiers">Familiers</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/encyclopedie/montures">Montures</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/encyclopedie/consommables">Consommables</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/encyclopedie/ressources">Ressources</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/encyclopedie/objets-d-apparat">Objets d'apparat </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </span>
# <li class="lvl0 ak-menu-brand">
# <a class="navbar-brand" href="/fr"></a>
# </li>
# <span class="ak-navbar-right-part">
# <li class="lvl0 sep">
# <a href="/fr/mmorpg/communaute/ladder">Ladders</a>
# </li>
# <li class="lvl0 dropdown sep">
# <a class="dropdown-toggle" data-toggle="dropdown" href="javascript:void(0);">Communauté <b class="caret"></b></a>
# <ul class="dropdown-menu dropdown-menu-right" role="menu">
# <li class="lvl1 nopointer">
# <a href="javascript:void(0);">Informations</a>
# <ul>
# <li class="lvl2">
# <a href="/fr/mmorpg/communaute/reglement">Règles de conduite</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/communaute/serveurs">Statut des serveurs</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/communaute/phishing">securité</a>
# </li>
# </ul>
# </li>
# <li class="lvl1 nopointer">
# <a href="javascript:void(0);">Annuaires</a>
# <ul>
# <li class="lvl2">
# <a href="/fr/mmorpg/communaute/annuaires/pages-persos">Pages perso</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/communaute/annuaires/pages-guildes">Guildes</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/communaute/annuaires/pages-artisans">Artisans</a>
# </li>
# </ul>
# </li>
# <li class="lvl1 nopointer">
# <a href="javascript:void(0);">le coin des joueurs</a>
# <ul>
# <li class="lvl2">
# <a href="/fr/forum">Forums</a>
# </li>
# <li class="lvl2">
# <a href="/fr/mmorpg/communaute/codes">Code Cadeau</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="lvl0 sep">
# <a href="/fr/forum">Forums</a>
# </li>
# </span>
# </ul>
# </div>
# <div class="ak-navbar-right ak-has-search">
# <div class="ak-nav-not-logged">
# <div class="ak-connect-links">
# <a class="login" href="https://account.ankama.com/webauth/authorize?from=https%3A%2F%2Fwww.dofus-touch.com%2Ffr%2Fmmorpg%2Fencyclopedie%2Fmetiers%2F28-paysan%3Fpage%3D2">
# <span>Connexion</span>
# <img alt="Avatar" class="img-responsive" src="https://static.ankama.com/web-avatar/0.png"/>
# </a>
# <!--a  href="http://www.dofus-touch.com/fr/mmorpg/jouer"  class="register">
#       Inscription    </a-->
# </div>
# </div> <a class="ak-navbar-search" data-navbar-search="">
# <div class="ak-form"><form action="/fr/recherche" class="ak-container" method="get" role="form">
# <div class="form-group">
# <input autocapitalize="off" autocorrect="off" class="form-control ak-autocomplete" name="q" type="text" value="Rechercher..."/><script type="application/json">{"minLength":1,"delay":0,"select":"location","url":"https:\/\/www.dofus-touch.com\/fr\/autocomplete","titlemax":45,"shownoresults":true,"noresults":"Voir tous les r\u00e9sultats"}</script>
# </div>
# <input class="" type="button" value="ok"/>
# </form></div> </a>
# </div>
# </div>
# </nav>
# <div class="ak-idbar-box ak-box-lang">
# <a class="ak-flag-fr" href="/fr/mmorpg/encyclopedie/metiers/28-paysan?page=2" hreflang="fr">FR</a>
# <a class="ak-flag-en" href="/en/mmorpg/encyclopedia/professions/28-paysan?page=2" hreflang="en">EN</a>
# <a class="ak-flag-es" href="/es/mmorpg/enciclopedia/oficios/28-paysan?page=2" hreflang="es">ES</a>
# </div>
# <!-- Keep in order largest -> lowest device resolution -->
# <div class="largedesktop device-profile visible-lg" data-deviceprofile="largedesktop"></div>
# <div class="desktop device-profile visible-md" data-deviceprofile="desktop"></div>
# <div class="tablet device-profile visible-sm" data-deviceprofile="tablet"></div>
# <div class="mobile device-profile visible-xs" data-deviceprofile="mobile"></div>
# </header>
# <aside class="ak-slidemenu">
# <div class="ak-navbar-search-mob">
# <form action="/fr/recherche" method="get">
# <input autocomplete="off" class="ak-autocomplete ui-autocomplete-input" name="q" type="text" value="Rechercher..."/>
# <script type="application/json">
#         {
#             "minLength":1,
#             "delay":0,
#             "select":"location",
#             "url":"https://www.dofus-touch.com/fr/autocomplete",
#             "titlemax":45,
#             "shownoresults":true,
#             "noresults":"Voir tous les résultats"
#         }
#         </script>
# <input type="submit" value=""/>
# <ul class="ui-autocomplete ui-front ui-menu ui-widget ui-widget-content" id="ui-id-1" style="display: none;" tabindex="0"></ul></form>
# </div>
# <div class="menu-container"></div>
# <div class="menu-buttons">
# <div class="ak-button-modal ak-flags-links">
# <a class="ak-flag" href="#"></a>
# </div>
# <script type="application/json">{"tooltip":{"position":{"my":"left top","at":"bottom left"},"hide":{"event":"mouseleave"}}}</script> <div class="ak-idbar-box ak-box-lang">
# <a class="ak-flag-fr" href="/fr/mmorpg/encyclopedie/metiers/28-paysan?page=2" hreflang="fr">FR</a>
# <a class="ak-flag-en" href="/en/mmorpg/encyclopedia/professions/28-paysan?page=2" hreflang="en">EN</a>
# <a class="ak-flag-es" href="/es/mmorpg/enciclopedia/oficios/28-paysan?page=2" hreflang="es">ES</a>
# </div>
# <a class="btn-default ak-support-link" href="https://support.ankama.com/hc/fr" target="_blank">Support</a>
# </div>
# </aside>
# <script type="application/json">{"triggerElement":".navbar-header .burger-btn","fromTarget":"header ul.nav.navbar-nav"}</script>
# <div class="ak-mobile-menu-scroller">
# <div class="ak-pagetop ak-container"><div class="ak-pagetop-child"><div class="ak-container container"><div><div class="row">
# <div class="col-xs-12 col-sm-9">
# <nav>
# <div class="ak-breadcrumb-spacer"></div>
# <div class="breadcrumb" itemscope="" itemtype="http://schema.org/BreadcrumbList">
# <div class="ak-first" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a href="/fr" itemprop="item">
# <span itemprop="name">Jeux multijoueur</span>
# <meta content="1" itemprop="position"/>
# </a>
# </div>
# <div itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a href="/fr/mmorpg/jouer" itemprop="item">
# <span itemprop="name">Encyclopédie</span>
# <meta content="2" itemprop="position"/>
# </a>
# </div>
# <div itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a href="/fr/mmorpg/encyclopedie/metiers" itemprop="item">
# <span itemprop="name">Métiers</span>
# <meta content="3" itemprop="position"/>
# </a>
# </div>
# </div>
# </nav>
# </div>
# <div class="col-xs-12 col-sm-3 text-center">
# <span> <div class="ak-block-store">
# <a href="https://itunes.apple.com/fr/app/dofus-touch/id1041406978" target="_blank">
# <img class="img-maxresponsive" src="https://static.ankama.com/g/modules/ankama/homepage/btn-stores/app-store-fr.png">
# </img></a>
# <a href="https://play.google.com/store/apps/details?id=com.ankama.dofustouch" target="_blank">
# <img class="img-maxresponsive" src="https://static.ankama.com/g/modules/ankama/homepage/btn-stores/google-play-fr.png">
# </img></a>
# </div>
# </span> </div>
# </div>
# </div></div></div></div>
# <div class="container ak-main-container">
# <div class="ak-main-content">
# <div class="ak-main-page">
# <div class="row">
# <main class="main col-md-9">
# <div class="ak-page-header">
# </div>
# <div class="ak-container ak-main-center"><div class="ak-container ak-panel-stack ak-glue"><div class="ak-nav-top ak-nav-expand">
# <div class="ak-nav-expand-container">
# <div class="ak-nav-expand-links">
# <a class="ak-link-page breeds" href="/fr/mmorpg/encyclopedie/classes">
# <span class="ak-icon-med ak-breeds"></span>
# </a>
# <span class="ak-tooltip hidden">Classes</span>
# <a class="ak-link-page selected jobs" href="/fr/mmorpg/encyclopedie/metiers">
# <span class="ak-icon-med ak-jobs"></span>
# </a>
# <span class="ak-tooltip hidden">Métiers</span>
# <a class="ak-link-page monsters" href="/fr/mmorpg/encyclopedie/monstres">
# <span class="ak-icon-med ak-monsters"></span>
# </a>
# <span class="ak-tooltip hidden">Bestiaire</span>
# <a class="ak-link-page weapons" href="/fr/mmorpg/encyclopedie/armes">
# <span class="ak-icon-med ak-weapons"></span>
# </a>
# <span class="ak-tooltip hidden">Armes</span>
# <a class="ak-link-page equipments" href="/fr/mmorpg/encyclopedie/equipements">
# <span class="ak-icon-med ak-equipments"></span>
# </a>
# <span class="ak-tooltip hidden">Equipements</span>
# <a class="ak-link-page sets" href="/fr/mmorpg/encyclopedie/panoplies">
# <span class="ak-icon-med ak-sets"></span>
# </a>
# <span class="ak-tooltip hidden">Panoplie</span>
# <a class="ak-link-page pets" href="/fr/mmorpg/encyclopedie/familiers">
# <span class="ak-icon-med ak-pets"></span>
# </a>
# <span class="ak-tooltip hidden">Familiers</span>
# <a class="ak-link-page rides" href="/fr/mmorpg/encyclopedie/montures">
# <span class="ak-icon-med ak-rides"></span>
# </a>
# <span class="ak-tooltip hidden">Montures</span>
# <a class="ak-link-page consumables" href="/fr/mmorpg/encyclopedie/consommables">
# <span class="ak-icon-med ak-consumables"></span>
# </a>
# <span class="ak-tooltip hidden">Consommables</span>
# <a class="ak-link-page ressources" href="/fr/mmorpg/encyclopedie/ressources">
# <span class="ak-icon-med ak-ressources"></span>
# </a>
# <span class="ak-tooltip hidden">Ressources</span>
# </div>
# </div>
# <div class="ak-nav-expand-more">
# <span class="ak-nav-expand-icon ak-picto-common ak-picto-open">+</span>
# </div>
# </div>
# <div class="ak-title-container ak-backlink">
# <h1 class="ak-return-link">
# <a href="">
# <span class="ak-icon-big ak-jobs"></span>
# </a>
#
#     Paysan
#       </h1>
# <a class="ak-backlink-button" href="/fr/mmorpg/encyclopedie/metiers">
#       Retour à la liste    </a>
# </div><div class="ak-container ak-panel">
# <div class="ak-panel-content">
# <div class="row ak-nocontentpadding">
# <div class="col-sm-3">
# <div class="ak-encyclo-detail-illu">
# <img class="img-responsive" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/28.jpg"/>
# </div>
# </div>
# <div class="col-sm-9">
# <div class="ak-container ak-panel"> <div class="ak-panel-title">
# <span class="ak-panel-title-icon"></span>
#             Description du métier
#           </div>
# <div class="ak-panel-content">
# <p>Le paysan consacre une partie de son temps à faucher des céréales dans les champs de la province d'Amakna, et l'autre partie à moudre le fruit de ses récoltes pour vendre ses farines aux boulangers les plus offrants.</p>
# </div>
# </div> </div>
# </div>
# </div>
# </div><div class="ak-container ak-tabs-container"><ul class="ak-container nav nav-tabs ak-tabs">
# <li class="tab1 active">
# <a class="ak-ajaxloader" data-target="div.tab-content" href="/fr/mmorpg/encyclopedie/metiers/28-paysan/recettes">
#       Recettes    </a>
# </li>
# </ul><div class="ak-container ak-tabs-body tab-content"> <div class="ak-tab" id="tab1">
# <div class="ak-container ak-panel ak-nocontentpadding">
# <div class="ak-panel-content">
# <table border="1" class="ak-container ak-table ak-responsivetable" data-options='{"ajaxDetails":true}'>
# <thead>
# <tr class="ak-ajaxloader" data-target="div.tab-content">
# <th class="img-first-column"></th> <th><a class="" href="/fr/mmorpg/encyclopedie/metiers/28-paysan?sort=1A">Nom<span class="ak-picto-common"></span></a></th> <th><a class="sort-asc" href="/fr/mmorpg/encyclopedie/metiers/28-paysan?sort=2D">Niveau<span class="ak-picto-common"></span></a></th> </tr>
# </thead>
# <tbody>
# <tr ajax-details-url="/fr/mmorpg/encyclopedie/objets/recette/587" class="ak-bg-odd">
# <td class="img-first-column"><img alt="Farine Complète" src="https://static.ankama.com/dofus-touch/www/img/../../../dofus-touch/www/game/items/52/52259.w40h40.png"/></td> <td><a href="/fr/mmorpg/encyclopedie/ressources/587-farine-complete">Farine Complète</a></td> <td class="ak-fixed-100">40</td> </tr>
# <tr ajax-details-url="/fr/mmorpg/encyclopedie/objets/recette/7068" class="ak-bg-even">
# <td class="img-first-column"><img alt="Farine de Riz" src="https://static.ankama.com/dofus-touch/www/img/../../../dofus-touch/www/game/items/52/52007.w40h40.png"/></td> <td><a href="/fr/mmorpg/encyclopedie/ressources/7068-farine-riz">Farine de Riz</a></td> <td class="ak-fixed-100">50</td> </tr>
# <tr ajax-details-url="/fr/mmorpg/encyclopedie/objets/recette/6672" class="ak-bg-odd">
# <td class="img-first-column"><img alt="Farine de Xavier le Boulanger" src="https://static.ankama.com/dofus-touch/www/img/../../../dofus-touch/www/game/items/52/52250.w40h40.png"/></td> <td><a href="/fr/mmorpg/encyclopedie/ressources/6672-farine-xavier-boulanger">Farine de Xavier le Boulanger</a></td> <td class="ak-fixed-100">100</td> </tr>
# <tr ajax-details-url="/fr/mmorpg/encyclopedie/objets/recette/11194" class="ak-bg-even">
# <td class="img-first-column"><img alt="Farine de Frostiz" src="https://static.ankama.com/dofus-touch/www/img/../../../dofus-touch/www/game/items/52/52260.w40h40.png"/></td> <td><a href="/fr/mmorpg/encyclopedie/ressources/11194-farine-frostiz">Farine de Frostiz</a></td> <td class="ak-fixed-100">100</td> </tr>
# <tr ajax-details-url="/fr/mmorpg/encyclopedie/objets/recette/11199" class="ak-bg-odd">
# <td class="img-first-column"><img alt="Graine de Frostiz" src="https://static.ankama.com/dofus-touch/www/img/../../../dofus-touch/www/game/items/52/58406.w40h40.png"/></td> <td><a href="/fr/mmorpg/encyclopedie/ressources/11199-graine-frostiz">Graine de Frostiz</a></td> <td class="ak-fixed-100">100</td> </tr>
# <tr ajax-details-url="/fr/mmorpg/encyclopedie/objets/recette/11497" class="ak-bg-even">
# <td class="img-first-column"><img alt="Huile de Frostiz" src="https://static.ankama.com/dofus-touch/www/img/../../../dofus-touch/www/game/items/52/60073.w40h40.png"/></td> <td><a href="/fr/mmorpg/encyclopedie/ressources/11497-huile-frostiz">Huile de Frostiz</a></td> <td class="ak-fixed-100">100</td> </tr>
# <tr ajax-details-url="/fr/mmorpg/encyclopedie/objets/recette/11502" class="ak-bg-odd">
# <td class="img-first-column"><img alt="Farine de Frostiz soufflé" src="https://static.ankama.com/dofus-touch/www/img/../../../dofus-touch/www/game/items/52/52261.w40h40.png"/></td> <td><a href="/fr/mmorpg/encyclopedie/ressources/11502-farine-frostiz-souffle">Farine de Frostiz soufflé</a></td> <td class="ak-fixed-100">100</td> </tr>
# </tbody>
# </table>
# <div class="text-center ak-pagination hidden-xs">
# <nav>
# <ul class="ak-pagination pagination ak-ajaxloader" data-target="div.tab-content">
# <li>
# <a href="/fr/mmorpg/encyclopedie/metiers/28-paysan?page=1">«</a>
# </li>
# <li>
# <a href="/fr/mmorpg/encyclopedie/metiers/28-paysan?page=1">
#         ‹      </a>
# </li>
# <li>
# <a href="/fr/mmorpg/encyclopedie/metiers/28-paysan?page=1">1</a>
# </li>
# <li class="disabled active">
# <a href="javascript:void(0);">2</a>
# </li>
# <li class="disabled">
# <a href="javascript:void(0);">
#         ›      </a>
# </li>
# <li class="disabled">
# <a href="javascript:void(0);">»</a>
# </li>
# </ul>
# <script type="application/json">{"scroll":true}</script> </nav>
# </div>
# <div class="text-center ak-pagination visible-xs">
# <nav>
# <ul class="ak-pagination pagination ak-ajaxloader" data-target="div.tab-content">
# <li>
# <a href="/fr/mmorpg/encyclopedie/metiers/28-paysan?page=1">
#         «
#       </a>
# </li>
# <li>
# <a href="/fr/mmorpg/encyclopedie/metiers/28-paysan?page=1">
#         ‹      </a>
# </li>
# <li class="disabled">
# <a href="javascript:void(0);">
#         ›      </a>
# </li>
# <li class="disabled">
# <a href="javascript:void(0);">
#         »
#       </a>
# </li>
# </ul>
# <script type="application/json">{"scroll":true}</script> </nav>
# </div>
# </div>
# </div> </div>
# </div></div><div class="ak-container"><div class="ak-social">
# <div class="pull-left">
# <div class="ak-social-block facebook">
# <a class="" href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww.dofus-touch.com%2Ffr%2Fmmorpg%2Fencyclopedie%2Fmetiers%2F28-paysan" onclick="javascript:window.open(this.href,'','menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=600,width=600');return false;">Partager</a> </div>
# <div class="ak-social-block twitter">
# <a class="" href="http://twitter.com/share?text=&amp;url=https%3A%2F%2Fwww.dofus-touch.com%2Ffr%2Fmmorpg%2Fencyclopedie%2Fmetiers%2F28-paysan" onclick="javascript:window.open(this.href,'','menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=600,width=600');return false;">Tweet</a> </div>
# </div>
# </div>
# </div><div class="ak-container ak-panel ak-lazyload" id="ak-block-posts">
# <div class="ak-panel-content">
#
#
#
# </div>
# </div><script type="application/json">{"ajaxSrc":"\/fr\/mmorpg\/encyclopedie\/metiers\/28-paysan?page=2&forum=1"}</script></div></div>
# </main>
# <aside class="col-md-3">
# <div class="ak-container ak-main-aside"><div class="ak-container ak-panel"> <div class="ak-panel-title">
# <span class="ak-panel-title-icon"></span>
#             Métiers
#           </div>
# <div class="ak-panel-content">
# <div class="ak-container ak-content-list"><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/26-alchimiste">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/26.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/26-alchimiste">
#                     Alchimiste                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/16-bijoutier">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/16.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/16-bijoutier">
#                     Bijoutier                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/56-boucher">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/56.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/56-boucher">
#                     Boucher                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/25-boulanger">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/25.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/25-boulanger">
#                     Boulanger                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/65-bricoleur">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/65.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/65-bricoleur">
#                     Bricoleur                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/2-bucheron">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/2.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/2-bucheron">
#                     Bûcheron                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/41-chasseur">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/41.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/41-chasseur">
#                     Chasseur                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/62-cordomage">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/62.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/62-cordomage">
#                     Cordomage                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/15-cordonnier">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/15.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/15-cordonnier">
#                     Cordonnier                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/64-costumage">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/64.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/64-costumage">
#                     Costumage                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/60-faconneur">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/60.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/60-faconneur">
#                     Façonneur                       </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/44-forgemage-epees">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/44.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/44-forgemage-epees">
#                     Forgemage d'Epées                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/43-forgemage-dagues">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/43.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/43-forgemage-dagues">
#                     Forgemage de Dagues                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/47-forgemage-haches">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/47.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/47-forgemage-haches">
#                     Forgemage de Haches                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/45-forgemage-marteaux">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/45.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/45-forgemage-marteaux">
#                     Forgemage de Marteaux                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/46-forgemage-pelles">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/46.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/46-forgemage-pelles">
#                     Forgemage de Pelles                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/11-forgeur-epees">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/11.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/11-forgeur-epees">
#                     Forgeur d'Epées                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/17-forgeur-dagues">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/17.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/17-forgeur-dagues">
#                     Forgeur de Dagues                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/31-forgeur-haches">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/31.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/31-forgeur-haches">
#                     Forgeur de Haches                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/14-forgeur-marteaux">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/14.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/14-forgeur-marteaux">
#                     Forgeur de Marteaux                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/20-forgeur-pelles">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/20.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/20-forgeur-pelles">
#                     Forgeur de Pelles                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/63-joaillomage">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/63.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/63-joaillomage">
#                     Joaillomage                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/24-mineur">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/24.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/24-mineur">
#                     Mineur                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/28-paysan">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/28.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/28-paysan">
#                     Paysan                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/36-pecheur">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/36.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/36-pecheur">
#                     Pêcheur                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/58-poissonnier">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/58.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/58-poissonnier">
#                     Poissonnier                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/48-sculptemage-arcs">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/48.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/48-sculptemage-arcs">
#                     Sculptemage d'Arcs                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/49-sculptemage-baguettes">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/49.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/49-sculptemage-baguettes">
#                     Sculptemage de Baguettes                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/50-sculptemage-batons">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/50.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/50-sculptemage-batons">
#                     Sculptemage de Bâtons                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/13-sculpteur-arcs">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/13.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/13-sculpteur-arcs">
#                     Sculpteur d'Arcs                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/19-sculpteur-baguettes">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/19.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/19-sculpteur-baguettes">
#                     Sculpteur de Baguettes                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/18-sculpteur-batons">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/18.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/18-sculpteur-batons">
#                     Sculpteur de Bâtons                      </a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="ak-list-element">
# <div class="ak-main">
# <div class="ak-main-content">
# <div class="ak-image">
# <a href="/fr/mmorpg/encyclopedie/metiers/27-tailleur">
# <img height="30" src="https://static.ankama.com/dofus-touch/www/img/../modules/mmorpg/encyclopedia/jobs/assets/images/27.w30h30.jpg" width="30"/> </a>
# </div>
# <div class="ak-content">
# <div class="ak-title">
# <a href="/fr/mmorpg/encyclopedie/metiers/27-tailleur">
#                     Tailleur                      </a>
# </div>
# </div>
# </div>
# </div>
# </div></div>
# </div>
# </div></div> </aside>
# </div>
# </div>
# </div>
# </div>
# <a class="ak-backtotop" href="javascript:void(0);"></a>
# <footer><div class="ak-footer-content">
# <div class="row ak-block1">
# <div class="col-md-9 ak-block-links">
# <div class="col-xs-4">
# <div class="ak-list">
# <div>
# <span class="ak-link-title">
#                     Le Jeu DOFUS Touch                  </span>
# </div>
# <a href="/fr/mmorpg/decouvrir">
#                             Découvrir                        </a>
# <a href="/fr/mmorpg/encyclopedie/classes">
#                             Encyclopédie                        </a>
# <a href="/fr/forum">
#                             Forum DOFUS Touch                        </a>
# </div>
# </div>
# <div class="col-xs-4">
# <div class="ak-list">
# <div>
# <span class="ak-link-title">
#                     MON COMPTE                  </span>
# </div>
# <a href="https://account.ankama.com/webauth/authorize?from=https%3A%2F%2Fwww.dofus-touch.com%2Ffr%2Fmmorpg%2Fencyclopedie%2Fmetiers%2F28-paysan%3Fpage%3D2">
#                             Se connecter                        </a>
# <a href="https://support.ankama.com/hc/fr/articles/115005030228" target="_blank">
#                             Sécurité du compte                        </a>
# </div>
# </div>
# <div class="col-xs-4">
# <div class="ak-list">
# <div>
# <span class="ak-link-title">
#                     SUPPORT                  </span>
# </div>
# <a href="https://support.ankama.com/hc/fr/requests/new?ticket_form_id=177158">
#                             Impossible de jouer                        </a>
# <a href="https://account.ankama.com/fr/compte/recuperation-mot-de-passe" target="_blank">
#                             Mot de passe perdu                        </a>
# <a href="https://account.ankama.com/fr/compte/securiser-mon-compte" target="_blank">
#                             Compte volé                        </a>
# <a href="https://support.ankama.com/hc/fr/requests/new">
#                             Nous Contacter                        </a>
# </div>
# </div>
# </div>
# <div class="col-md-3 ak-block-download">
# <a class="btn btn-primary btn-lg" href="/fr/mmorpg/telecharger">
#               Télécharger le jeu            </a>
# <div class="ak-social-network">
# <a class="fb" href="https://www.facebook.com/DOFUSTouch" target="_blank"></a>
# <a class="tw" href="https://twitter.com/dofustouch" target="_blank"></a>
# <a class="yo" href="https://www.youtube.com/user/dofus" target="_blank"></a>
# </div>
# </div>
# </div>
# <div class="row ak_legal">
# <div id="col-md-12">
# <div class="ak-legal">
# <div class="row">
# <div class="col-sm-1"><a class="ak-logo-ankama" href="https://www.ankama.com" target="_blank"></a></div>
# <div class="col-sm-7">
# <p>© 2024 <a href="http://www.ankama-group.com/fr" target="_blank">Ankama</a>. Tous droits réservés. <a href="https://www.dofus-touch.com/fr/cgu" target="_blank">Conditions d'utilisation</a> - <a href="https://www.dofus-touch.com/fr/politique-confidentialite" target="_blank">Politique de confidentialité</a> - <a href="https://www.dofus-touch.com/fr/cgv" target="_blank">Conditions Générales de Vente</a> - <a href="https://www.dofus-touch.com/fr/mentions-legales?ref=dofus-touch" target="_blank">Mentions Légales</a> - <a class="ak-modal-trigger" href="javascript:void(0);">Gestion des cookies</a><script type="application/json">{"target":".ak-modal-privacy-cookies"}</script> - </p>
# </div>
# <div class="col-sm-4">
# <span class="prevention"></span>
# </div>
# </div>
# </div> </div>
# </div>
# <div class="ak-lazyload-notifications" data-position="FOOTER" style="display: none"></div>
# <div class="payment">
# <dib class="row">
# <div class="col-xs-2"><img class="img-maxresponsive" src="https://static.ankama.com/g/modules/masterpage/block/footer/logos/visa.jpg"/></div>
# <div class="col-xs-2"><img class="img-maxresponsive" src="https://static.ankama.com/g/modules/masterpage/block/footer/logos/pp.jpg"/></div>
# <div class="col-xs-2"><img class="img-maxresponsive" src="https://static.ankama.com/g/modules/masterpage/block/footer/logos/mc.jpg"/></div>
# <div class="col-xs-2"><img class="img-maxresponsive" src="https://static.ankama.com/g/modules/masterpage/block/footer/logos/ae.jpg"/></div>
# <div class="col-xs-2"><img class="img-maxresponsive" src="https://static.ankama.com/g/modules/masterpage/block/footer/logos/paysafe.jpg"/></div>
# <div class="col-xs-2"><img class="img-maxresponsive" src="https://static.ankama.com/g/modules/masterpage/block/footer/logos/xsola.jpg"/></div>
# </dib>
# </div>
# </div>
# <div class="ak-modal-privacy-cookies ak-modal" title="Gestion de vos préférences sur les cookies"> <p>
# <div class="ak-block-cookies-infobox">
# <p>Ce site utilise des cookies destinés à réaliser des statistiques de visites ainsi qu'à vous proposer des vidéos, des boutons de partage sur les réseaux sociaux, des<br/>
# publicités personnalisées et un service de chat.<br/>
# <br/>
# Nous conservons votre choix pendant 6 mois.<br/>
# Vous pouvez changer d'avis à tout moment en cliquant sur le bouton " Gestion des cookies " en bas de chaque page de notre site.</p>
# <div class="text-center">
# <a class="ak-text-link" href="https://account.ankama.com/fr/politique-confidentialite" target="_blank">
#             En savoir plus sur notre politique de cookies        </a>
# </div>
# <div class="ak-block-btns">
# <button action="show-settings" class="btn btn-info btn-lg ak-custom">
#              personnaliser mes choix        </button>
# <button action="refuse-all" class="btn btn-info btn-lg ak-refuse">
#             tout refuser        </button>
# <button action="accept-all" class="btn btn-primary btn-lg ak-accept">
#              tout accepter        </button>
# </div>
# </div>
# <div class="ak-privacy-cookies-manager">
# <p class="ak-intro">Certaines fonctionnalités de ce site (partage de contenus sur les réseaux sociaux, lecture directe de vidéos) s'appuient sur des services proposés par des sites tiers. Ces fonctionnalités déposent des cookies permettant notamment à ces sites de tracer votre navigation. Ces cookies ne sont déposés que si vous donnez votre accord. Vous pouvez vous informer sur la nature des cookies déposés, les accepter ou les refuser soit globalement pour l'ensemble du site et l'ensemble des services, soit service par service.</p>
# <hr/>
# <div class="ak-group" group="_all">
# <h3>Tous</h3>
# <p>Préférences pour tous les services</p>
# <div class="ak-block" key="_all">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Tous                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="ak-group" group="audience">
# <h3>Audience et Publicité</h3>
# <p>Les cookies d'audience permettent de recueillir des informations relatives à la connexion et au comportement des visiteurs à des fins statistiques</p>
# <div class="ak-block" key="_all">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Tous                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# <div class="ak-block" key="fbtr">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Facebook tracker                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# <div class="ak-block" key="ggan">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Google Analytics                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# <div class="ak-block" key="otad">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Autres outils publicitaires                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="ak-group" group="social_networks">
# <h3>Réseaux sociaux</h3>
# <p>Les réseaux sociaux permettent d'améliorer la convivialité du site et aident à sa promotion via les partages.</p>
# <div class="ak-block" key="_all">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Tous                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# <div class="ak-block" key="fbok">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Facebook                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# <div class="ak-block" key="ggpl">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Google Plus                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# <div class="ak-block" key="twtr">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Twitter                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# <div class="ak-block" key="dsrd">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Discord                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# <div class="ak-block" key="pwro">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Powr Io                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="ak-group" group="medias">
# <h3>Média</h3>
# <p>Les services de médias permettent d'enrichir le site de contenu multimédia et augmentent sa visibilité.</p>
# <div class="ak-block" key="_all">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Tous                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# <div class="ak-block" key="ytbe">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Youtube                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# <div class="ak-block" key="twch">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Twitch                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# <div class="ak-block" key="gphy">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Giphy                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="ak-group" group="other">
# <h3>Autre</h3>
# <p>Des cookies de confort pour améliorer l'expérience utilisateur</p>
# <div class="ak-block" key="_all">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Tous                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# <div class="ak-block" key="ggmp">
# <div class="row">
# <div class="col-xs-6 text-right ak-label">
#                             Google Maps                        </div>
# <div class="col-xs-6">
# <button action="y" class="btn btn-sm btn-primary">Autoriser</button>
# <button action="n" class="btn btn-sm btn-danger">Interdire</button>
# </div>
# </div>
# </div>
# </div>
# </div></p>
# </div><script type="application/json">{"dialog":{"dialogClass":"ak-modal-wrapper"}}</script></footer>
# <div class="ak-mobile-menu-overlay"></div>
# </div>
# <script src="https://static.ankama.com/g/common.js" type="text/javascript"></script>
# <script src="https://static.ankama.com/dofus-touch/www/javascript/../modules/common/common.js" type="text/javascript"></script>
# </body>
# </html>

# %%
all_recipes
# Out:
# [{'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1642',
#   'object_id': 1642,
#   'object_name': "Potion d'oubli de métier : Forgemage de Dagues",
#   'link': '/fr/mmorpg/encyclopedie/consommables/1642-potion-oubli-metier-forgemage-dagues',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1643',
#   'object_id': 1643,
#   'object_name': "Potion d'oubli de métier : Forgemage de Haches",
#   'link': '/fr/mmorpg/encyclopedie/consommables/1643-potion-oubli-metier-forgemage-haches',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1644',
#   'object_id': 1644,
#   'object_name': "Potion d'oubli de métier : Forgemage de Marteaux",
#   'link': '/fr/mmorpg/encyclopedie/consommables/1644-potion-oubli-metier-forgemage-marteaux',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1645',
#   'object_id': 1645,
#   'object_name': "Potion d'oubli de métier : Forgemage d'Epées",
#   'link': '/fr/mmorpg/encyclopedie/consommables/1645-potion-oubli-metier-forgemage-epees',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1646',
#   'object_id': 1646,
#   'object_name': "Potion d'oubli de métier : Forgemage de Pelles",
#   'link': '/fr/mmorpg/encyclopedie/consommables/1646-potion-oubli-metier-forgemage-pelles',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1647',
#   'object_id': 1647,
#   'object_name': "Potion d'oubli de métier : Sculptemage d'Arcs",
#   'link': '/fr/mmorpg/encyclopedie/consommables/1647-potion-oubli-metier-sculptemage-arcs',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1648',
#   'object_id': 1648,
#   'object_name': "Potion d'oubli de métier : Sculptemage de Baguettes",
#   'link': '/fr/mmorpg/encyclopedie/consommables/1648-potion-oubli-metier-sculptemage-baguettes',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1649',
#   'object_id': 1649,
#   'object_name': "Potion d'oubli de métier : Sculptemage de Bâtons",
#   'link': '/fr/mmorpg/encyclopedie/consommables/1649-potion-oubli-metier-sculptemage-batons',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2183',
#   'object_id': 2183,
#   'object_name': "Potion d'oubli de métier : Pêcheur",
#   'link': '/fr/mmorpg/encyclopedie/consommables/2183-potion-oubli-metier-pecheur',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2184',
#   'object_id': 2184,
#   'object_name': "Potion d'oubli de métier : Poissonnier",
#   'link': '/fr/mmorpg/encyclopedie/consommables/2184-potion-oubli-metier-poissonnier',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2185',
#   'object_id': 2185,
#   'object_name': "Potion d'oubli de métier : Chasseur",
#   'link': '/fr/mmorpg/encyclopedie/consommables/2185-potion-oubli-metier-chasseur',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2186',
#   'object_id': 2186,
#   'object_name': "Potion d'oubli de métier : Boucher",
#   'link': '/fr/mmorpg/encyclopedie/consommables/2186-potion-oubli-metier-boucher',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2542',
#   'object_id': 2542,
#   'object_name': 'Potion de Foyer',
#   'link': '/fr/mmorpg/encyclopedie/consommables/2542-potion-foyer',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6964',
#   'object_id': 6964,
#   'object_name': 'Potion de cité :  Brâkmar',
#   'link': '/fr/mmorpg/encyclopedie/consommables/6964-potion-cite-brakmar',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6965',
#   'object_id': 6965,
#   'object_name': 'Potion de cité :  Bonta',
#   'link': '/fr/mmorpg/encyclopedie/consommables/6965-potion-cite-bonta',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7421',
#   'object_id': 7421,
#   'object_name': "Potion d'oubli de métier : Façonneur",
#   'link': '/fr/mmorpg/encyclopedie/consommables/7421-potion-oubli-metier-faconneur',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7505',
#   'object_id': 7505,
#   'object_name': "Potion d'oubli de métier : Costumage",
#   'link': '/fr/mmorpg/encyclopedie/consommables/7505-potion-oubli-metier-costumage',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7506',
#   'object_id': 7506,
#   'object_name': "Potion d'oubli de métier : Joaillomage",
#   'link': '/fr/mmorpg/encyclopedie/consommables/7506-potion-oubli-metier-joaillomage',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7507',
#   'object_id': 7507,
#   'object_name': "Potion d'oubli de métier : Cordomage",
#   'link': '/fr/mmorpg/encyclopedie/consommables/7507-potion-oubli-metier-cordomage',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7652',
#   'object_id': 7652,
#   'object_name': 'Potion de Souvenir',
#   'link': '/fr/mmorpg/encyclopedie/consommables/7652-potion-souvenir',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8106',
#   'object_id': 8106,
#   'object_name': "Potion d'oubli de métier : Bricoleur",
#   'link': '/fr/mmorpg/encyclopedie/consommables/8106-potion-oubli-metier-bricoleur',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8883',
#   'object_id': 8883,
#   'object_name': 'Potion de Foyer de Guilde',
#   'link': '/fr/mmorpg/encyclopedie/consommables/8883-potion-foyer-guilde',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/9035',
#   'object_id': 9035,
#   'object_name': "Potion d'enclos de Guilde",
#   'link': '/fr/mmorpg/encyclopedie/consommables/9035-potion-enclos-guilde',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10031',
#   'object_id': 10031,
#   'object_name': 'Teinture Orange Sanguine',
#   'link': '/fr/mmorpg/encyclopedie/ressources/10031-teinture-orange-sanguine',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10208',
#   'object_id': 10208,
#   'object_name': 'Elixir Pandawa',
#   'link': '/fr/mmorpg/encyclopedie/consommables/10208-elixir-pandawa',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10209',
#   'object_id': 10209,
#   'object_name': 'Elixir Sacrieur',
#   'link': '/fr/mmorpg/encyclopedie/consommables/10209-elixir-sacrieur',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10210',
#   'object_id': 10210,
#   'object_name': 'Elixir Eniripsa',
#   'link': '/fr/mmorpg/encyclopedie/consommables/10210-elixir-eniripsa',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10211',
#   'object_id': 10211,
#   'object_name': 'Elixir Sadida',
#   'link': '/fr/mmorpg/encyclopedie/consommables/10211-elixir-sadida',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10212',
#   'object_id': 10212,
#   'object_name': 'Elixir Crâ',
#   'link': '/fr/mmorpg/encyclopedie/consommables/10212-elixir-cra',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10213',
#   'object_id': 10213,
#   'object_name': 'Elixir Iop',
#   'link': '/fr/mmorpg/encyclopedie/consommables/10213-elixir-iop',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10214',
#   'object_id': 10214,
#   'object_name': 'Elixir Ecaflip',
#   'link': '/fr/mmorpg/encyclopedie/consommables/10214-elixir-ecaflip',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10215',
#   'object_id': 10215,
#   'object_name': 'Elixir Xélor',
#   'link': '/fr/mmorpg/encyclopedie/consommables/10215-elixir-xelor',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10216',
#   'object_id': 10216,
#   'object_name': 'Elixir Féca',
#   'link': '/fr/mmorpg/encyclopedie/consommables/10216-elixir-feca',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10217',
#   'object_id': 10217,
#   'object_name': 'Elixir Enutrof',
#   'link': '/fr/mmorpg/encyclopedie/consommables/10217-elixir-enutrof',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10218',
#   'object_id': 10218,
#   'object_name': 'Elixir Osamodas',
#   'link': '/fr/mmorpg/encyclopedie/consommables/10218-elixir-osamodas',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10219',
#   'object_id': 10219,
#   'object_name': 'Elixir Sram',
#   'link': '/fr/mmorpg/encyclopedie/consommables/10219-elixir-sram',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10669',
#   'object_id': 10669,
#   'object_name': 'Potion de crapaud-mufle',
#   'link': '/fr/mmorpg/encyclopedie/consommables/10669-potion-crapaud-mufle',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10673',
#   'object_id': 10673,
#   'object_name': 'Potion de HmmMmm',
#   'link': '/fr/mmorpg/encyclopedie/consommables/10673-potion-hmmmmm',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10715',
#   'object_id': 10715,
#   'object_name': 'Poudre de Créatoune',
#   'link': '/fr/mmorpg/encyclopedie/ressources/10715-poudre-creatoune',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10750',
#   'object_id': 10750,
#   'object_name': "Potion d'Amélioration d'Atouin",
#   'link': '/fr/mmorpg/encyclopedie/objets/10750-potion-amelioration-atouin',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10751',
#   'object_id': 10751,
#   'object_name': "Potion d'Amélioration de Bébé Pandawa",
#   'link': '/fr/mmorpg/encyclopedie/objets/10751-potion-amelioration-bebe-pandawa',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10752',
#   'object_id': 10752,
#   'object_name': "Potion d'Amélioration de Bilby",
#   'link': '/fr/mmorpg/encyclopedie/objets/10752-potion-amelioration-bilby',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10753',
#   'object_id': 10753,
#   'object_name': "Potion d'Amélioration de Bwak",
#   'link': '/fr/mmorpg/encyclopedie/objets/10753-potion-amelioration-bwak',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10754',
#   'object_id': 10754,
#   'object_name': "Potion d'Amélioration de Bworky",
#   'link': '/fr/mmorpg/encyclopedie/objets/10754-potion-amelioration-bworky',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10755',
#   'object_id': 10755,
#   'object_name': "Potion d'Amélioration de Chacha",
#   'link': '/fr/mmorpg/encyclopedie/objets/10755-potion-amelioration-chacha',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10756',
#   'object_id': 10756,
#   'object_name': "Potion d'Amélioration de Chacha Angora",
#   'link': '/fr/mmorpg/encyclopedie/objets/10756-potion-amelioration-chacha-angora',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10757',
#   'object_id': 10757,
#   'object_name': "Potion d'Amélioration de Chacha Tigré",
#   'link': '/fr/mmorpg/encyclopedie/objets/10757-potion-amelioration-chacha-tigre',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10758',
#   'object_id': 10758,
#   'object_name': "Potion d'Amélioration de Crocodaille",
#   'link': '/fr/mmorpg/encyclopedie/objets/10758-potion-amelioration-crocodaille',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10759',
#   'object_id': 10759,
#   'object_name': "Potion d'Amélioration d'Ecureuil Chenapan",
#   'link': '/fr/mmorpg/encyclopedie/objets/10759-potion-amelioration-ecureuil-chenapan',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10760',
#   'object_id': 10760,
#   'object_name': "Potion d'Amélioration de Fëanor",
#   'link': '/fr/mmorpg/encyclopedie/objets/10760-potion-amelioration-feanor',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10761',
#   'object_id': 10761,
#   'object_name': "Potion d'Amélioration de Koalak Sanguin",
#   'link': '/fr/mmorpg/encyclopedie/objets/10761-potion-amelioration-koalak-sanguin',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10762',
#   'object_id': 10762,
#   'object_name': "Potion d'Amélioration de Kouin-Kouin",
#   'link': '/fr/mmorpg/encyclopedie/objets/10762-potion-amelioration-kouin-kouin',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10763',
#   'object_id': 10763,
#   'object_name': "Potion d'Amélioration de Léopardo",
#   'link': '/fr/mmorpg/encyclopedie/objets/10763-potion-amelioration-leopardo',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10764',
#   'object_id': 10764,
#   'object_name': "Potion d'Amélioration de Mini Wa",
#   'link': '/fr/mmorpg/encyclopedie/objets/10764-potion-amelioration-mini-wa',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10765',
#   'object_id': 10765,
#   'object_name': "Potion d'Amélioration de Nomoon",
#   'link': '/fr/mmorpg/encyclopedie/objets/10765-potion-amelioration-nomoon',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10766',
#   'object_id': 10766,
#   'object_name': "Potion d'Amélioration de Péki",
#   'link': '/fr/mmorpg/encyclopedie/objets/10766-potion-amelioration-peki',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10767',
#   'object_id': 10767,
#   'object_name': "Potion d'Amélioration de Petit Chacha Blanc",
#   'link': '/fr/mmorpg/encyclopedie/objets/10767-potion-amelioration-petit-chacha-blanc',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10768',
#   'object_id': 10768,
#   'object_name': "Potion d'Amélioration de Petit Chienchien Noir",
#   'link': '/fr/mmorpg/encyclopedie/objets/10768-potion-amelioration-petit-chienchien-noir',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10769',
#   'object_id': 10769,
#   'object_name': "Potion d'Amélioration de Pioute",
#   'link': '/fr/mmorpg/encyclopedie/objets/10769-potion-amelioration-pioute',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10770',
#   'object_id': 10770,
#   'object_name': "Potion d'Amélioration de Ross",
#   'link': '/fr/mmorpg/encyclopedie/objets/10770-potion-amelioration-ross',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10771',
#   'object_id': 10771,
#   'object_name': "Potion d'Amélioration de Vilain Petit Corbac",
#   'link': '/fr/mmorpg/encyclopedie/objets/10771-potion-amelioration-vilain-petit-corbac',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10772',
#   'object_id': 10772,
#   'object_name': "Potion d'Amélioration de Wabbit",
#   'link': '/fr/mmorpg/encyclopedie/objets/10772-potion-amelioration-wabbit',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10773',
#   'object_id': 10773,
#   'object_name': "Potion d'Amélioration de Walk",
#   'link': '/fr/mmorpg/encyclopedie/objets/10773-potion-amelioration-walk',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10774',
#   'object_id': 10774,
#   'object_name': "Potion d'Amélioration de Willy le Relou",
#   'link': '/fr/mmorpg/encyclopedie/objets/10774-potion-amelioration-willy-relou',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10776',
#   'object_id': 10776,
#   'object_name': "Potion d'Amélioration de Miniminotot",
#   'link': '/fr/mmorpg/encyclopedie/objets/10776-potion-amelioration-miniminotot',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10777',
#   'object_id': 10777,
#   'object_name': "Potion d'Amélioration de Tiwabbit Kiafin",
#   'link': '/fr/mmorpg/encyclopedie/objets/10777-potion-amelioration-tiwabbit-kiafin',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10778',
#   'object_id': 10778,
#   'object_name': "Potion d'Amélioration de Chauffe-Souris",
#   'link': '/fr/mmorpg/encyclopedie/objets/10778-potion-amelioration-chauffe-souris',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10779',
#   'object_id': 10779,
#   'object_name': "Potion d'Amélioration de Dragoune Noire",
#   'link': '/fr/mmorpg/encyclopedie/objets/10779-potion-amelioration-dragoune-noire',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10780',
#   'object_id': 10780,
#   'object_name': "Potion d'Amélioration de Bouloute du Parrain",
#   'link': '/fr/mmorpg/encyclopedie/objets/10780-potion-amelioration-bouloute-parrain',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10781',
#   'object_id': 10781,
#   'object_name': "Potion d'Amélioration de Gelutin",
#   'link': '/fr/mmorpg/encyclopedie/objets/10781-potion-amelioration-gelutin',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10782',
#   'object_id': 10782,
#   'object_name': "Potion d'Amélioration de Shushu de Rushu",
#   'link': '/fr/mmorpg/encyclopedie/objets/10782-potion-amelioration-shushu-rushu',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10783',
#   'object_id': 10783,
#   'object_name': "Potion d'Amélioration de Vampyrette",
#   'link': '/fr/mmorpg/encyclopedie/objets/10783-potion-amelioration-vampyrette',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10809',
#   'object_id': 10809,
#   'object_name': "Potion d'Amélioration de Dragoune Dorée",
#   'link': '/fr/mmorpg/encyclopedie/objets/10809-potion-amelioration-dragoune-doree',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10811',
#   'object_id': 10811,
#   'object_name': "Potion d'Amélioration de Goultus",
#   'link': '/fr/mmorpg/encyclopedie/objets/10811-potion-amelioration-goultus',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10827',
#   'object_id': 10827,
#   'object_name': 'Potion de soin larvesque',
#   'link': '/fr/mmorpg/encyclopedie/consommables/10827-potion-soin-larvesque',
#   'level': 1,
#   'profession': 'Alchimiste'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/82',
#   'object_id': 82,
#   'object_name': 'Amulette du Loup',
#   'link': '/fr/mmorpg/encyclopedie/equipements/82-amulette-loup',
#   'level': 2,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/786',
#   'object_id': 786,
#   'object_name': 'Pendentif du Hibou Chétif',
#   'link': '/fr/mmorpg/encyclopedie/equipements/786-pendentif-hibou-chetif',
#   'level': 2,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/787',
#   'object_id': 787,
#   'object_name': 'Anneau Rexik',
#   'link': '/fr/mmorpg/encyclopedie/equipements/787-anneau-rexik',
#   'level': 2,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/851',
#   'object_id': 851,
#   'object_name': 'Anneau Vitalesque',
#   'link': '/fr/mmorpg/encyclopedie/equipements/851-anneau-vitalesque',
#   'level': 2,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/849',
#   'object_id': 849,
#   'object_name': 'Anneau Forcesque',
#   'link': '/fr/mmorpg/encyclopedie/equipements/849-anneau-forcesque',
#   'level': 3,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/850',
#   'object_id': 850,
#   'object_name': 'Anneau Agilesque',
#   'link': '/fr/mmorpg/encyclopedie/equipements/850-anneau-agilesque',
#   'level': 3,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8538',
#   'object_id': 8538,
#   'object_name': "Le S'Mesme",
#   'link': '/fr/mmorpg/encyclopedie/equipements/8538-mesme',
#   'level': 3,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/768',
#   'object_id': 768,
#   'object_name': 'Camaïneux',
#   'link': '/fr/mmorpg/encyclopedie/equipements/768-camaineux',
#   'level': 4,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8537',
#   'object_id': 8537,
#   'object_name': 'Le Plussain',
#   'link': '/fr/mmorpg/encyclopedie/equipements/8537-plussain',
#   'level': 5,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/74',
#   'object_id': 74,
#   'object_name': "Petite Amulette de l'Ours",
#   'link': '/fr/mmorpg/encyclopedie/equipements/74-petite-amulette-ours',
#   'level': 6,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/767',
#   'object_id': 767,
#   'object_name': 'Gantie Royal',
#   'link': '/fr/mmorpg/encyclopedie/equipements/767-gantie-royal',
#   'level': 6,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2475',
#   'object_id': 2475,
#   'object_name': "Anneau de l'Aventurier",
#   'link': '/fr/mmorpg/encyclopedie/equipements/2475-anneau-aventurier',
#   'level': 7,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/101',
#   'object_id': 101,
#   'object_name': 'Anneau de Sagesse',
#   'link': '/fr/mmorpg/encyclopedie/equipements/101-anneau-sagesse',
#   'level': 8,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/280',
#   'object_id': 280,
#   'object_name': "Collier de l'Arc en Ciel",
#   'link': '/fr/mmorpg/encyclopedie/equipements/280-collier-arc-ciel',
#   'level': 8,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/766',
#   'object_id': 766,
#   'object_name': 'Koliet Aclou',
#   'link': '/fr/mmorpg/encyclopedie/equipements/766-koliet-aclou',
#   'level': 8,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2478',
#   'object_id': 2478,
#   'object_name': "Amulette de l'Aventurier",
#   'link': '/fr/mmorpg/encyclopedie/equipements/2478-amulette-aventurier',
#   'level': 8,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/279',
#   'object_id': 279,
#   'object_name': 'La Larme du Bouftou',
#   'link': '/fr/mmorpg/encyclopedie/equipements/279-larme-bouftou',
#   'level': 9,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/324',
#   'object_id': 324,
#   'object_name': 'Amulette de Krokette',
#   'link': '/fr/mmorpg/encyclopedie/equipements/324-amulette-krokette',
#   'level': 9,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/110',
#   'object_id': 110,
#   'object_name': 'Anneau de Chance',
#   'link': '/fr/mmorpg/encyclopedie/equipements/110-anneau-chance',
#   'level': 10,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/119',
#   'object_id': 119,
#   'object_name': "Anneau d'Agilité",
#   'link': '/fr/mmorpg/encyclopedie/equipements/119-anneau-agilite',
#   'level': 10,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/785',
#   'object_id': 785,
#   'object_name': 'Anneau Fortifiant',
#   'link': '/fr/mmorpg/encyclopedie/equipements/785-anneau-fortifiant',
#   'level': 10,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/856',
#   'object_id': 856,
#   'object_name': 'Grenouillette',
#   'link': '/fr/mmorpg/encyclopedie/equipements/856-grenouillette',
#   'level': 10,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/158',
#   'object_id': 158,
#   'object_name': 'La Destinée Dorée',
#   'link': '/fr/mmorpg/encyclopedie/equipements/158-destinee-doree',
#   'level': 12,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/355',
#   'object_id': 355,
#   'object_name': "L'Anneau de Valeur",
#   'link': '/fr/mmorpg/encyclopedie/equipements/355-anneau-valeur',
#   'level': 12,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/764',
#   'object_id': 764,
#   'object_name': 'Amulette du Petit Hibou',
#   'link': '/fr/mmorpg/encyclopedie/equipements/764-amulette-petit-hibou',
#   'level': 12,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/854',
#   'object_id': 854,
#   'object_name': 'Amulette du Petit Ours',
#   'link': '/fr/mmorpg/encyclopedie/equipements/854-amulette-petit-ours',
#   'level': 12,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1330',
#   'object_id': 1330,
#   'object_name': 'Amulette Itby',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1330-amulette-itby',
#   'level': 12,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1490',
#   'object_id': 1490,
#   'object_name': 'La Chaîne Nhanor Kibrill',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1490-chaine-nhanor-kibrill',
#   'level': 13,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1087',
#   'object_id': 1087,
#   'object_name': 'Anneau du Mental',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1087-anneau-mental',
#   'level': 14,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/278',
#   'object_id': 278,
#   'object_name': 'Anneau des Rocheuses',
#   'link': '/fr/mmorpg/encyclopedie/equipements/278-anneau-rocheuses',
#   'level': 15,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1493',
#   'object_id': 1493,
#   'object_name': 'Blessure du Sacrieur',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1493-blessure-sacrieur',
#   'level': 15,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1494',
#   'object_id': 1494,
#   'object_name': 'Le Bagueur',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1494-bagueur',
#   'level': 15,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2396',
#   'object_id': 2396,
#   'object_name': 'La Lou Ptiote',
#   'link': '/fr/mmorpg/encyclopedie/equipements/2396-lou-ptiote',
#   'level': 15,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2399',
#   'object_id': 2399,
#   'object_name': 'La Veaux Doux',
#   'link': '/fr/mmorpg/encyclopedie/equipements/2399-veaux-doux',
#   'level': 15,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/157',
#   'object_id': 157,
#   'object_name': 'La Gougnole',
#   'link': '/fr/mmorpg/encyclopedie/equipements/157-gougnole',
#   'level': 17,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/346',
#   'object_id': 346,
#   'object_name': 'Anneau Rak',
#   'link': '/fr/mmorpg/encyclopedie/equipements/346-anneau-rak',
#   'level': 17,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/841',
#   'object_id': 841,
#   'object_name': 'Anneau de Satisfaction',
#   'link': '/fr/mmorpg/encyclopedie/equipements/841-anneau-satisfaction',
#   'level': 17,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2393',
#   'object_id': 2393,
#   'object_name': 'Omelette Amulette',
#   'link': '/fr/mmorpg/encyclopedie/equipements/2393-omelette-amulette',
#   'level': 17,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7122',
#   'object_id': 7122,
#   'object_name': 'Anneau Vice',
#   'link': '/fr/mmorpg/encyclopedie/equipements/7122-anneau-vice',
#   'level': 18,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6723',
#   'object_id': 6723,
#   'object_name': "Amulette de l'Homme Ours",
#   'link': '/fr/mmorpg/encyclopedie/equipements/6723-amulette-homme-ours',
#   'level': 20,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7880',
#   'object_id': 7880,
#   'object_name': 'Amulette du Boufcoul',
#   'link': '/fr/mmorpg/encyclopedie/equipements/7880-amulette-boufcoul',
#   'level': 20,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8213',
#   'object_id': 8213,
#   'object_name': 'Amulette du Piou Rouge',
#   'link': '/fr/mmorpg/encyclopedie/equipements/8213-amulette-piou-rouge',
#   'level': 20,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8214',
#   'object_id': 8214,
#   'object_name': 'Amulette du Piou Bleu',
#   'link': '/fr/mmorpg/encyclopedie/equipements/8214-amulette-piou-bleu',
#   'level': 20,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8215',
#   'object_id': 8215,
#   'object_name': 'Amulette du Piou Violet',
#   'link': '/fr/mmorpg/encyclopedie/equipements/8215-amulette-piou-violet',
#   'level': 20,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8216',
#   'object_id': 8216,
#   'object_name': 'Amulette du Piou Vert',
#   'link': '/fr/mmorpg/encyclopedie/equipements/8216-amulette-piou-vert',
#   'level': 20,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8217',
#   'object_id': 8217,
#   'object_name': 'Amulette du Piou Jaune',
#   'link': '/fr/mmorpg/encyclopedie/equipements/8217-amulette-piou-jaune',
#   'level': 20,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8218',
#   'object_id': 8218,
#   'object_name': 'Amulette du Piou Rose',
#   'link': '/fr/mmorpg/encyclopedie/equipements/8218-amulette-piou-rose',
#   'level': 20,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/616',
#   'object_id': 616,
#   'object_name': 'Amulette du Marin',
#   'link': '/fr/mmorpg/encyclopedie/equipements/616-amulette-marin',
#   'level': 22,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/783',
#   'object_id': 783,
#   'object_name': 'Amulette du Bûcheron',
#   'link': '/fr/mmorpg/encyclopedie/equipements/783-amulette-bucheron',
#   'level': 22,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1485',
#   'object_id': 1485,
#   'object_name': 'La Reinette',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1485-reinette',
#   'level': 22,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6722',
#   'object_id': 6722,
#   'object_name': "Alliance de l'Homme Ours",
#   'link': '/fr/mmorpg/encyclopedie/equipements/6722-alliance-homme-ours',
#   'level': 22,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1496',
#   'object_id': 1496,
#   'object_name': "Chance d'Ecaflip",
#   'link': '/fr/mmorpg/encyclopedie/equipements/1496-chance-ecaflip',
#   'level': 23,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8219',
#   'object_id': 8219,
#   'object_name': 'Anneau du Piou Rouge',
#   'link': '/fr/mmorpg/encyclopedie/equipements/8219-anneau-piou-rouge',
#   'level': 23,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8220',
#   'object_id': 8220,
#   'object_name': 'Anneau du Piou Bleu',
#   'link': '/fr/mmorpg/encyclopedie/equipements/8220-anneau-piou-bleu',
#   'level': 23,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8222',
#   'object_id': 8222,
#   'object_name': 'Anneau du Piou Vert',
#   'link': '/fr/mmorpg/encyclopedie/equipements/8222-anneau-piou-vert',
#   'level': 23,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8223',
#   'object_id': 8223,
#   'object_name': 'Anneau du Piou Jaune',
#   'link': '/fr/mmorpg/encyclopedie/equipements/8223-anneau-piou-jaune',
#   'level': 23,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8224',
#   'object_id': 8224,
#   'object_name': 'Anneau du Piou Rose',
#   'link': '/fr/mmorpg/encyclopedie/equipements/8224-anneau-piou-rose',
#   'level': 23,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/610',
#   'object_id': 610,
#   'object_name': 'Amulette en Crabe',
#   'link': '/fr/mmorpg/encyclopedie/equipements/610-amulette-crabe',
#   'level': 24,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6961',
#   'object_id': 6961,
#   'object_name': 'Anneau du Bandit',
#   'link': '/fr/mmorpg/encyclopedie/equipements/6961-anneau-bandit',
#   'level': 24,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6923',
#   'object_id': 6923,
#   'object_name': 'Amulette du Bandit',
#   'link': '/fr/mmorpg/encyclopedie/equipements/6923-amulette-bandit',
#   'level': 25,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/12851',
#   'object_id': 12851,
#   'object_name': 'Bracelet du Glutin',
#   'link': '/fr/mmorpg/encyclopedie/equipements/12851-bracelet-glutin',
#   'level': 25,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/732',
#   'object_id': 732,
#   'object_name': 'Alliance de Silimelle',
#   'link': '/fr/mmorpg/encyclopedie/equipements/732-alliance-silimelle',
#   'level': 26,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1481',
#   'object_id': 1481,
#   'object_name': 'Entente',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1481-entente',
#   'level': 26,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1656',
#   'object_id': 1656,
#   'object_name': 'Fécaliseur du Magicien',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1656-fecaliseur-magicien',
#   'level': 26,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1657',
#   'object_id': 1657,
#   'object_name': 'Fécaliseur du Guerrier',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1657-fecaliseur-guerrier',
#   'level': 26,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8221',
#   'object_id': 8221,
#   'object_name': 'Anneau du Piou Violet',
#   'link': '/fr/mmorpg/encyclopedie/equipements/8221-anneau-piou-violet',
#   'level': 26,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/161',
#   'object_id': 161,
#   'object_name': 'La Célébrité',
#   'link': '/fr/mmorpg/encyclopedie/equipements/161-celebrite',
#   'level': 27,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1489',
#   'object_id': 1489,
#   'object_name': 'La Broche Hète',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1489-broche-hete',
#   'level': 28,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6789',
#   'object_id': 6789,
#   'object_name': 'Amulette des Champs',
#   'link': '/fr/mmorpg/encyclopedie/equipements/6789-amulette-champs',
#   'level': 28,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6791',
#   'object_id': 6791,
#   'object_name': 'Anneau Champêtre',
#   'link': '/fr/mmorpg/encyclopedie/equipements/6791-anneau-champetre',
#   'level': 28,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/359',
#   'object_id': 359,
#   'object_name': "L'Ecaliseur",
#   'link': '/fr/mmorpg/encyclopedie/equipements/359-ecaliseur',
#   'level': 29,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1483',
#   'object_id': 1483,
#   'object_name': 'Kabale',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1483-kabale',
#   'level': 29,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6466',
#   'object_id': 6466,
#   'object_name': 'Amulette de Shika',
#   'link': '/fr/mmorpg/encyclopedie/equipements/6466-amulette-shika',
#   'level': 29,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6910',
#   'object_id': 6910,
#   'object_name': 'Anneau du Sanglier',
#   'link': '/fr/mmorpg/encyclopedie/equipements/6910-anneau-sanglier',
#   'level': 29,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1497',
#   'object_id': 1497,
#   'object_name': 'Passé de Xélor',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1497-passe-xelor',
#   'level': 30,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1498',
#   'object_id': 1498,
#   'object_name': "Souvenir d'Enutrof",
#   'link': '/fr/mmorpg/encyclopedie/equipements/1498-souvenir-enutrof',
#   'level': 30,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2397',
#   'object_id': 2397,
#   'object_name': 'La Bibelaw',
#   'link': '/fr/mmorpg/encyclopedie/equipements/2397-bibelaw',
#   'level': 30,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1486',
#   'object_id': 1486,
#   'object_name': 'Médaille Holy',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1486-medaille-holy',
#   'level': 31,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6920',
#   'object_id': 6920,
#   'object_name': 'Alliance Du Champ Champ',
#   'link': '/fr/mmorpg/encyclopedie/equipements/6920-alliance-champ-champ',
#   'level': 31,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6999',
#   'object_id': 6999,
#   'object_name': 'Médaille Lahilama',
#   'link': '/fr/mmorpg/encyclopedie/equipements/6999-medaille-lahilama',
#   'level': 31,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8881',
#   'object_id': 8881,
#   'object_name': 'Anneau Solo',
#   'link': '/fr/mmorpg/encyclopedie/equipements/8881-anneau-solo',
#   'level': 31,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2389',
#   'object_id': 2389,
#   'object_name': 'Amulette du Badoul',
#   'link': '/fr/mmorpg/encyclopedie/equipements/2389-amulette-badoul',
#   'level': 32,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2394',
#   'object_id': 2394,
#   'object_name': 'La Bourgeonette',
#   'link': '/fr/mmorpg/encyclopedie/equipements/2394-bourgeonette',
#   'level': 32,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8126',
#   'object_id': 8126,
#   'object_name': 'Mitaines Mitées du Paysan',
#   'link': '/fr/mmorpg/encyclopedie/equipements/8126-mitaines-mitees-paysan',
#   'level': 32,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/325',
#   'object_id': 325,
#   'object_name': 'Amulette du Sram',
#   'link': '/fr/mmorpg/encyclopedie/equipements/325-amulette-sram',
#   'level': 33,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/326',
#   'object_id': 326,
#   'object_name': 'Amulette Deulegarnoulle',
#   'link': '/fr/mmorpg/encyclopedie/equipements/326-amulette-deulegarnoulle',
#   'level': 33,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6915',
#   'object_id': 6915,
#   'object_name': 'Mos Kitano',
#   'link': '/fr/mmorpg/encyclopedie/equipements/6915-mos-kitano',
#   'level': 33,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6919',
#   'object_id': 6919,
#   'object_name': 'Anneau du Champ Champ',
#   'link': '/fr/mmorpg/encyclopedie/equipements/6919-anneau-champ-champ',
#   'level': 33,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8123',
#   'object_id': 8123,
#   'object_name': 'Amulette Paysanne',
#   'link': '/fr/mmorpg/encyclopedie/equipements/8123-amulette-paysanne',
#   'level': 33,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1662',
#   'object_id': 1662,
#   'object_name': 'Ambramulette Arakne',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1662-ambramulette-arakne',
#   'level': 34,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6911',
#   'object_id': 6911,
#   'object_name': 'Araknoton',
#   'link': '/fr/mmorpg/encyclopedie/equipements/6911-araknoton',
#   'level': 34,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/638',
#   'object_id': 638,
#   'object_name': 'Amulette du Pêcheur de Somoon',
#   'link': '/fr/mmorpg/encyclopedie/equipements/638-amulette-pecheur-somoon',
#   'level': 35,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/458',
#   'object_id': 458,
#   'object_name': 'Amulette du Chafer',
#   'link': '/fr/mmorpg/encyclopedie/equipements/458-amulette-chafer',
#   'level': 36,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1495',
#   'object_id': 1495,
#   'object_name': "L'Anneau Dhyn",
#   'link': '/fr/mmorpg/encyclopedie/equipements/1495-anneau-dhyn',
#   'level': 36,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/867',
#   'object_id': 867,
#   'object_name': 'Dragolyre',
#   'link': '/fr/mmorpg/encyclopedie/equipements/867-dragolyre',
#   'level': 37,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/916',
#   'object_id': 916,
#   'object_name': 'Amulette de Silicate',
#   'link': '/fr/mmorpg/encyclopedie/equipements/916-amulette-silicate',
#   'level': 37,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7246',
#   'object_id': 7246,
#   'object_name': 'Alliance Akwadala',
#   'link': '/fr/mmorpg/encyclopedie/equipements/7246-alliance-akwadala',
#   'level': 37,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1480',
#   'object_id': 1480,
#   'object_name': 'Accord',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1480-accord',
#   'level': 38,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6928',
#   'object_id': 6928,
#   'object_name': 'Anneau du Prespic',
#   'link': '/fr/mmorpg/encyclopedie/equipements/6928-anneau-prespic',
#   'level': 38,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7881',
#   'object_id': 7881,
#   'object_name': 'Anneau du Boufcoul',
#   'link': '/fr/mmorpg/encyclopedie/equipements/7881-anneau-boufcoul',
#   'level': 38,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6459',
#   'object_id': 6459,
#   'object_name': 'Amulette du Mineur Sombre',
#   'link': '/fr/mmorpg/encyclopedie/equipements/6459-amulette-mineur-sombre',
#   'level': 39,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/159',
#   'object_id': 159,
#   'object_name': 'La Broche Céleste',
#   'link': '/fr/mmorpg/encyclopedie/equipements/159-broche-celeste',
#   'level': 40,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1661',
#   'object_id': 1661,
#   'object_name': 'Ambramulette Moskito',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1661-ambramulette-moskito',
#   'level': 40,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1718',
#   'object_id': 1718,
#   'object_name': 'Force de Crocoburio',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1718-force-crocoburio',
#   'level': 40,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2419',
#   'object_id': 2419,
#   'object_name': 'Anneau du Bouftou',
#   'link': '/fr/mmorpg/encyclopedie/equipements/2419-anneau-bouftou',
#   'level': 40,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2498',
#   'object_id': 2498,
#   'object_name': 'Vegamu',
#   'link': '/fr/mmorpg/encyclopedie/equipements/2498-vegamu',
#   'level': 40,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6464',
#   'object_id': 6464,
#   'object_name': "Anneau de l'Invocateur Satisfait",
#   'link': '/fr/mmorpg/encyclopedie/equipements/6464-anneau-invocateur-satisfait',
#   'level': 40,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7000',
#   'object_id': 7000,
#   'object_name': 'Bambamulette',
#   'link': '/fr/mmorpg/encyclopedie/equipements/7000-bambamulette',
#   'level': 40,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/17518',
#   'object_id': 17518,
#   'object_name': 'Abranneau',
#   'link': '/fr/mmorpg/encyclopedie/equipements/17518-abranneau',
#   'level': 40,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/617',
#   'object_id': 617,
#   'object_name': 'Amulette du Pirate',
#   'link': '/fr/mmorpg/encyclopedie/equipements/617-amulette-pirate',
#   'level': 41,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1482',
#   'object_id': 1482,
#   'object_name': 'Emblème Livide',
#   'link': '/fr/mmorpg/encyclopedie/equipements/1482-embleme-livide',
#   'level': 41,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2425',
#   'object_id': 2425,
#   'object_name': 'Amulette du Bouftou',
#   'link': '/fr/mmorpg/encyclopedie/equipements/2425-amulette-bouftou',
#   'level': 41,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7250',
#   'object_id': 7250,
#   'object_name': 'Amulette Akwadala',
#   'link': '/fr/mmorpg/encyclopedie/equipements/7250-amulette-akwadala',
#   'level': 41,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/11083',
#   'object_id': 11083,
#   'object_name': 'Bague de Boufbowl',
#   'link': '/fr/mmorpg/encyclopedie/equipements/11083-bague-boufbowl',
#   'level': 41,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2392',
#   'object_id': 2392,
#   'object_name': 'Dragolyre Remaniée',
#   'link': '/fr/mmorpg/encyclopedie/equipements/2392-dragolyre-remaniee',
#   'level': 42,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2395',
#   'object_id': 2395,
#   'object_name': 'Le foulard du Lard Fou',
#   'link': '/fr/mmorpg/encyclopedie/equipements/2395-foulard-lard-fou',
#   'level': 42,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2418',
#   'object_id': 2418,
#   'object_name': 'Kwakanneau de Flammes',
#   'link': '/fr/mmorpg/encyclopedie/equipements/2418-kwakanneau-flammes',
#   'level': 42,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2420',
#   'object_id': 2420,
#   'object_name': 'Anobra',
#   'link': '/fr/mmorpg/encyclopedie/equipements/2420-anobra',
#   'level': 42,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2424',
#   'object_id': 2424,
#   'object_name': 'Amukwak de Flammes',
#   'link': '/fr/mmorpg/encyclopedie/equipements/2424-amukwak-flammes',
#   'level': 42,
#   'profession': 'Bijoutier'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6731',
#   'object_id': 6731,
#   'object_name': 'Amukwak de Glace',
#   'link': '/fr/mmorpg/encyclopedie/equipements/6731-amukwak-glace',
#   'level': 42,
#   'profession': 'Bijoutier'},
# ...
#   'link': '/fr/mmorpg/encyclopedie/ressources/12351-clef-donjon-rats-chateau-amakna',
#   'level': 150,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8307',
#   'object_id': 8307,
#   'object_name': 'Clef de la salle du Minotot',
#   'link': '/fr/mmorpg/encyclopedie/ressources/8307-clef-salle-minotot',
#   'level': 160,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8977',
#   'object_id': 8977,
#   'object_name': 'Clef de la Canopée du Kimbo',
#   'link': '/fr/mmorpg/encyclopedie/ressources/8977-clef-canopee-kimbo',
#   'level': 160,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/11177',
#   'object_id': 11177,
#   'object_name': "Clef de l'hypogée de l'Obsidiantre",
#   'link': '/fr/mmorpg/encyclopedie/ressources/11177-clef-hypogee-obsidiantre',
#   'level': 160,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/16012',
#   'object_id': 16012,
#   'object_name': 'Clef de la Pyramide du Roi Skaille',
#   'link': '/fr/mmorpg/encyclopedie/ressources/16012-clef-pyramide-roi-skaille',
#   'level': 160,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/17096',
#   'object_id': 17096,
#   'object_name': 'Clef de la Chapelle inondée',
#   'link': '/fr/mmorpg/encyclopedie/ressources/17096-clef-chapelle-inondee',
#   'level': 160,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/11178',
#   'object_id': 11178,
#   'object_name': 'Clef de la Tanière Givrefoux',
#   'link': '/fr/mmorpg/encyclopedie/ressources/11178-clef-taniere-givrefoux',
#   'level': 170,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/17630',
#   'object_id': 17630,
#   'object_name': 'Clef de la Vallée de la Dame des eaux',
#   'link': '/fr/mmorpg/encyclopedie/ressources/17630-clef-vallee-dame-eaux',
#   'level': 170,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6884',
#   'object_id': 6884,
#   'object_name': 'Clef du Donjon du Bworker',
#   'link': '/fr/mmorpg/encyclopedie/ressources/6884-clef-donjon-bworker',
#   'level': 180,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/9247',
#   'object_id': 9247,
#   'object_name': 'Clef du Donjon Fungus',
#   'link': '/fr/mmorpg/encyclopedie/ressources/9247-clef-donjon-fungus',
#   'level': 180,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/11179',
#   'object_id': 11179,
#   'object_name': "Clef de l'Antre du Korriandre",
#   'link': '/fr/mmorpg/encyclopedie/ressources/11179-clef-antre-korriandre',
#   'level': 180,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/12152',
#   'object_id': 12152,
#   'object_name': 'Clef de la Maison du Papa Nowel',
#   'link': '/fr/mmorpg/encyclopedie/ressources/12152-clef-maison-papa-nowel',
#   'level': 180,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/17122',
#   'object_id': 17122,
#   'object_name': "Clef de l'Antre du Kralamoure Géant",
#   'link': '/fr/mmorpg/encyclopedie/ressources/17122-clef-antre-kralamoure-geant',
#   'level': 180,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/17632',
#   'object_id': 17632,
#   'object_name': "Clef de l'Atelier du Tanukouï San",
#   'link': '/fr/mmorpg/encyclopedie/ressources/17632-clef-atelier-tanukoui-san',
#   'level': 180,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8329',
#   'object_id': 8329,
#   'object_name': 'Clef de la mine de Sakaï',
#   'link': '/fr/mmorpg/encyclopedie/ressources/8329-clef-mine-sakai',
#   'level': 190,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/11180',
#   'object_id': 11180,
#   'object_name': 'Clef des cavernes du Kolosso',
#   'link': '/fr/mmorpg/encyclopedie/ressources/11180-clef-cavernes-kolosso',
#   'level': 190,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/11181',
#   'object_id': 11181,
#   'object_name': "Clef de l'Antichambre des Gloursons",
#   'link': '/fr/mmorpg/encyclopedie/ressources/11181-clef-antichambre-gloursons',
#   'level': 190,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/17636',
#   'object_id': 17636,
#   'object_name': "Clef de la Fabrique de foux d'artifice",
#   'link': '/fr/mmorpg/encyclopedie/ressources/17636-clef-fabrique-foux-artifice',
#   'level': 190,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/14043',
#   'object_id': 14043,
#   'object_name': 'Clef de la Forgefroide de Missiz Frizz',
#   'link': '/fr/mmorpg/encyclopedie/ressources/14043-clef-forgefroide-missiz-frizz',
#   'level': 200,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/14044',
#   'object_id': 14044,
#   'object_name': 'Clef du Transporteur de Sylargh',
#   'link': '/fr/mmorpg/encyclopedie/ressources/14044-clef-transporteur-sylargh',
#   'level': 200,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/14045',
#   'object_id': 14045,
#   'object_name': 'Clef des Salons privés de Klime',
#   'link': '/fr/mmorpg/encyclopedie/ressources/14045-clef-salons-prives-klime',
#   'level': 200,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/14046',
#   'object_id': 14046,
#   'object_name': 'Clef du Laboratoire de Nileza',
#   'link': '/fr/mmorpg/encyclopedie/ressources/14046-clef-laboratoire-nileza',
#   'level': 200,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/14047',
#   'object_id': 14047,
#   'object_name': 'Clef du Donjon du Comte Harebourg',
#   'link': '/fr/mmorpg/encyclopedie/ressources/14047-clef-donjon-comte-harebourg',
#   'level': 200,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/15090',
#   'object_id': 15090,
#   'object_name': 'Clef du Goulden Palace',
#   'link': '/fr/mmorpg/encyclopedie/ressources/15090-clef-goulden-palace',
#   'level': 200,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/17634',
#   'object_id': 17634,
#   'object_name': 'Clef du Dojo du vent',
#   'link': '/fr/mmorpg/encyclopedie/ressources/17634-clef-dojo-vent',
#   'level': 200,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/17638',
#   'object_id': 17638,
#   'object_name': 'Clef de la Bambusaie de Damadrya',
#   'link': '/fr/mmorpg/encyclopedie/ressources/17638-clef-bambusaie-damadrya',
#   'level': 200,
#   'profession': 'Bricoleur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1977',
#   'object_id': 1977,
#   'object_name': 'Épices',
#   'link': '/fr/mmorpg/encyclopedie/ressources/1977-epices',
#   'level': 1,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1987',
#   'object_id': 1987,
#   'object_name': "Viande d'Oiseau Conservée",
#   'link': '/fr/mmorpg/encyclopedie/ressources/1987-viande-oiseau-conservee',
#   'level': 1,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1990',
#   'object_id': 1990,
#   'object_name': 'Chair de Larve Conservée',
#   'link': '/fr/mmorpg/encyclopedie/ressources/1990-chair-larve-conservee',
#   'level': 1,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1993',
#   'object_id': 1993,
#   'object_name': "Chair d'Insecte Conservée",
#   'link': '/fr/mmorpg/encyclopedie/ressources/1993-chair-insecte-conservee',
#   'level': 1,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1991',
#   'object_id': 1991,
#   'object_name': 'Chair de Larve Conservée **',
#   'link': '/fr/mmorpg/encyclopedie/ressources/1991-chair-larve-conservee',
#   'level': 10,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1995',
#   'object_id': 1995,
#   'object_name': 'Cuisse de Bouftou Conservée',
#   'link': '/fr/mmorpg/encyclopedie/ressources/1995-cuisse-bouftou-conservee',
#   'level': 10,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1992',
#   'object_id': 1992,
#   'object_name': 'Chair de Larve Conservée ***',
#   'link': '/fr/mmorpg/encyclopedie/ressources/1992-chair-larve-conservee',
#   'level': 20,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1997',
#   'object_id': 1997,
#   'object_name': 'Cuisse de Bouftou Conservée **',
#   'link': '/fr/mmorpg/encyclopedie/ressources/1997-cuisse-bouftou-conservee',
#   'level': 20,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2000',
#   'object_id': 2000,
#   'object_name': 'Cuisse de Wabbit Conservée',
#   'link': '/fr/mmorpg/encyclopedie/ressources/2000-cuisse-wabbit-conservee',
#   'level': 20,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2004',
#   'object_id': 2004,
#   'object_name': 'Carré de Porc Conservé',
#   'link': '/fr/mmorpg/encyclopedie/ressources/2004-carre-porc-conserve',
#   'level': 30,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2008',
#   'object_id': 2008,
#   'object_name': 'Museau Conservé',
#   'link': '/fr/mmorpg/encyclopedie/ressources/2008-museau-conserve',
#   'level': 30,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1988',
#   'object_id': 1988,
#   'object_name': "Viande d'Oiseau Conservée **",
#   'link': '/fr/mmorpg/encyclopedie/ressources/1988-viande-oiseau-conservee',
#   'level': 40,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1998',
#   'object_id': 1998,
#   'object_name': 'Cuisse de Bouftou Conservée ***',
#   'link': '/fr/mmorpg/encyclopedie/ressources/1998-cuisse-bouftou-conservee',
#   'level': 40,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2001',
#   'object_id': 2001,
#   'object_name': 'Cuisse de Wabbit Conservée **',
#   'link': '/fr/mmorpg/encyclopedie/ressources/2001-cuisse-wabbit-conservee',
#   'level': 40,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2014',
#   'object_id': 2014,
#   'object_name': 'Dragoviande Conservée',
#   'link': '/fr/mmorpg/encyclopedie/ressources/2014-dragoviande-conservee',
#   'level': 40,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1994',
#   'object_id': 1994,
#   'object_name': "Chair d'Insecte Conservée **",
#   'link': '/fr/mmorpg/encyclopedie/ressources/1994-chair-insecte-conservee',
#   'level': 50,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1999',
#   'object_id': 1999,
#   'object_name': 'Cuisse de Bouftou Conservée ****',
#   'link': '/fr/mmorpg/encyclopedie/ressources/1999-cuisse-bouftou-conservee',
#   'level': 50,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2005',
#   'object_id': 2005,
#   'object_name': 'Carré de Porc Conservé **',
#   'link': '/fr/mmorpg/encyclopedie/ressources/2005-carre-porc-conserve',
#   'level': 50,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2009',
#   'object_id': 2009,
#   'object_name': 'Museau Conservé **',
#   'link': '/fr/mmorpg/encyclopedie/ressources/2009-museau-conserve',
#   'level': 50,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/15762',
#   'object_id': 15762,
#   'object_name': "Viande d'Oiseau Conservée ***",
#   'link': '/fr/mmorpg/encyclopedie/ressources/15762-viande-oiseau-conservee',
#   'level': 50,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1989',
#   'object_id': 1989,
#   'object_name': "Viande d'Oiseau Conservée ****",
#   'link': '/fr/mmorpg/encyclopedie/ressources/1989-viande-oiseau-conservee',
#   'level': 60,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2002',
#   'object_id': 2002,
#   'object_name': 'Cuisse de Wabbit Conservée ***',
#   'link': '/fr/mmorpg/encyclopedie/ressources/2002-cuisse-wabbit-conservee',
#   'level': 60,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2006',
#   'object_id': 2006,
#   'object_name': 'Carré de Porc Conservé ***',
#   'link': '/fr/mmorpg/encyclopedie/ressources/2006-carre-porc-conserve',
#   'level': 60,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2015',
#   'object_id': 2015,
#   'object_name': 'Dragoviande Conservée **',
#   'link': '/fr/mmorpg/encyclopedie/ressources/2015-dragoviande-conservee',
#   'level': 60,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2007',
#   'object_id': 2007,
#   'object_name': 'Carré de Porc Conservé ****',
#   'link': '/fr/mmorpg/encyclopedie/ressources/2007-carre-porc-conserve',
#   'level': 70,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2010',
#   'object_id': 2010,
#   'object_name': 'Museau Conservé ***',
#   'link': '/fr/mmorpg/encyclopedie/ressources/2010-museau-conserve',
#   'level': 70,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2016',
#   'object_id': 2016,
#   'object_name': 'Dragoviande Conservée ***',
#   'link': '/fr/mmorpg/encyclopedie/ressources/2016-dragoviande-conservee',
#   'level': 70,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8503',
#   'object_id': 8503,
#   'object_name': 'Viande de Crocodaille Conservée',
#   'link': '/fr/mmorpg/encyclopedie/ressources/8503-viande-crocodaille-conservee',
#   'level': 70,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2003',
#   'object_id': 2003,
#   'object_name': 'Cuisse de Wabbit Conservée ****',
#   'link': '/fr/mmorpg/encyclopedie/ressources/2003-cuisse-wabbit-conservee',
#   'level': 80,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8501',
#   'object_id': 8501,
#   'object_name': 'Viande de Kanigrou Conservée',
#   'link': '/fr/mmorpg/encyclopedie/ressources/8501-viande-kanigrou-conservee',
#   'level': 80,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/17394',
#   'object_id': 17394,
#   'object_name': 'Viande de Kanigrou Conservée **',
#   'link': '/fr/mmorpg/encyclopedie/ressources/17394-viande-kanigrou-conservee',
#   'level': 80,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/17396',
#   'object_id': 17396,
#   'object_name': 'Viande de Kanigrou Conservée ****',
#   'link': '/fr/mmorpg/encyclopedie/ressources/17396-viande-kanigrou-conservee',
#   'level': 80,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2017',
#   'object_id': 2017,
#   'object_name': 'Dragoviande Conservée ****',
#   'link': '/fr/mmorpg/encyclopedie/ressources/2017-dragoviande-conservee',
#   'level': 90,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/11483',
#   'object_id': 11483,
#   'object_name': 'Cuisse de Boufmouth conservée',
#   'link': '/fr/mmorpg/encyclopedie/ressources/11483-cuisse-boufmouth-conservee',
#   'level': 100,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/11674',
#   'object_id': 11674,
#   'object_name': 'Viande de Rat Bougri conservée',
#   'link': '/fr/mmorpg/encyclopedie/ressources/11674-viande-rat-bougri-conservee',
#   'level': 100,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/11675',
#   'object_id': 11675,
#   'object_name': 'Viande de Chachachovage conservée',
#   'link': '/fr/mmorpg/encyclopedie/ressources/11675-viande-chachachovage-conservee',
#   'level': 100,
#   'profession': 'Chasseur'},
#  {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/11676',
#   'object_id': 11676,
#   'object_name': 'Viande de Gélikan conservée',
#   'link': '/fr/mmorpg/encyclopedie/ressources/11676-viande-gelikan-conservee',
#   'level': 100,
#   'profession': 'Chasseur'},
#  ...]

# %%
len(all_recipes)
# Out:
# 1839

# %%
professions
# Out:
# {'Alchimiste': {'link': '/fr/mmorpg/encyclopedie/metiers/26-alchimiste',
#   'recipes': [{'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1642',
#     'object_id': 1642,
#     'object_name': "Potion d'oubli de métier : Forgemage de Dagues",
#     'link': '/fr/mmorpg/encyclopedie/consommables/1642-potion-oubli-metier-forgemage-dagues',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/armes/340-leurnettes',
#       'name': 'Leurnettes'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1643',
#     'object_id': 1643,
#     'object_name': "Potion d'oubli de métier : Forgemage de Haches",
#     'link': '/fr/mmorpg/encyclopedie/consommables/1643-potion-oubli-metier-forgemage-haches',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/armes/2589-hachette-hevlalav',
#       'name': 'Hachette Hévlalav'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1644',
#     'object_id': 1644,
#     'object_name': "Potion d'oubli de métier : Forgemage de Marteaux",
#     'link': '/fr/mmorpg/encyclopedie/consommables/1644-potion-oubli-metier-forgemage-marteaux',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/armes/9961-marteau-martel',
#       'name': 'Marteau Martel'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1645',
#     'object_id': 1645,
#     'object_name': "Potion d'oubli de métier : Forgemage d'Epées",
#     'link': '/fr/mmorpg/encyclopedie/consommables/1645-potion-oubli-metier-forgemage-epees',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/armes/47-epee-fouraille',
#       'name': 'Epée de Fouraille'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1646',
#     'object_id': 1646,
#     'object_name': "Potion d'oubli de métier : Forgemage de Pelles",
#     'link': '/fr/mmorpg/encyclopedie/consommables/1646-potion-oubli-metier-forgemage-pelles',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/armes/239-pelle-crapouille',
#       'name': 'Pelle de Crapouille'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1647',
#     'object_id': 1647,
#     'object_name': "Potion d'oubli de métier : Sculptemage d'Arcs",
#     'link': '/fr/mmorpg/encyclopedie/consommables/1647-potion-oubli-metier-sculptemage-arcs',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/armes/829-arc-hade',
#       'name': 'Arc Hade'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1648',
#     'object_id': 1648,
#     'object_name': "Potion d'oubli de métier : Sculptemage de Baguettes",
#     'link': '/fr/mmorpg/encyclopedie/consommables/1648-potion-oubli-metier-sculptemage-baguettes',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/armes/1356-demi-baguette',
#       'name': 'Demi-Baguette'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/1649',
#     'object_id': 1649,
#     'object_name': "Potion d'oubli de métier : Sculptemage de Bâtons",
#     'link': '/fr/mmorpg/encyclopedie/consommables/1649-potion-oubli-metier-sculptemage-batons',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/armes/183-baton-feuillu',
#       'name': 'Bâton Feuillu'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2183',
#     'object_id': 2183,
#     'object_name': "Potion d'oubli de métier : Pêcheur",
#     'link': '/fr/mmorpg/encyclopedie/consommables/2183-potion-oubli-metier-pecheur',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1782-goujon',
#       'name': 'Goujon'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2184',
#     'object_id': 2184,
#     'object_name': "Potion d'oubli de métier : Poissonnier",
#     'link': '/fr/mmorpg/encyclopedie/consommables/2184-potion-oubli-metier-poissonnier',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/consommables/1752-poisson-pane-frit',
#       'name': 'Poisson pané frit **'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2185',
#     'object_id': 2185,
#     'object_name': "Potion d'oubli de métier : Chasseur",
#     'link': '/fr/mmorpg/encyclopedie/consommables/2185-potion-oubli-metier-chasseur',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1896-viande-oiseau',
#       'name': "Viande d'Oiseau"}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2186',
#     'object_id': 2186,
#     'object_name': "Potion d'oubli de métier : Boucher",
#     'link': '/fr/mmorpg/encyclopedie/consommables/2186-potion-oubli-metier-boucher',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'},
#      {'count': '5',
#       'link': '/fr/mmorpg/encyclopedie/consommables/1947-nuggets',
#       'name': 'Nuggets'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2542',
#     'object_id': 2542,
#     'object_name': 'Potion de Foyer',
#     'link': '/fr/mmorpg/encyclopedie/consommables/2542-potion-foyer',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/428-fleur-chanvre',
#       'name': 'Fleur de Chanvre'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/2357-bois-oliviolet',
#       'name': "Bois d'Oliviolet"},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/16045-piraniak',
#       'name': 'Piraniak'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6964',
#     'object_id': 6964,
#     'object_name': 'Potion de cité :  Brâkmar',
#     'link': '/fr/mmorpg/encyclopedie/consommables/6964-potion-cite-brakmar',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/7018-riz',
#       'name': 'Riz'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/consommables/7047-fiole-pandapils',
#       'name': 'Une fiole de Pandapils'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6965',
#     'object_id': 6965,
#     'object_name': 'Potion de cité :  Bonta',
#     'link': '/fr/mmorpg/encyclopedie/consommables/6965-potion-cite-bonta',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/7018-riz',
#       'name': 'Riz'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/consommables/7045-fiole-pandaburg',
#       'name': 'Une fiole de Pandaburg'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7421',
#     'object_id': 7421,
#     'object_name': "Potion d'oubli de métier : Façonneur",
#     'link': '/fr/mmorpg/encyclopedie/consommables/7421-potion-oubli-metier-faconneur',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/441-cuivre',
#       'name': 'Cuivre'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7505',
#     'object_id': 7505,
#     'object_name': "Potion d'oubli de métier : Costumage",
#     'link': '/fr/mmorpg/encyclopedie/consommables/7505-potion-oubli-metier-costumage',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/equipements/8533-floude',
#       'name': 'Le Floude'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7506',
#     'object_id': 7506,
#     'object_name': "Potion d'oubli de métier : Joaillomage",
#     'link': '/fr/mmorpg/encyclopedie/consommables/7506-potion-oubli-metier-joaillomage',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/equipements/851-anneau-vitalesque',
#       'name': 'Anneau Vitalesque'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7507',
#     'object_id': 7507,
#     'object_name': "Potion d'oubli de métier : Cordomage",
#     'link': '/fr/mmorpg/encyclopedie/consommables/7507-potion-oubli-metier-cordomage',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/equipements/8536-spamette',
#       'name': 'La Spamette'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7652',
#     'object_id': 7652,
#     'object_name': 'Potion de Souvenir',
#     'link': '/fr/mmorpg/encyclopedie/consommables/7652-potion-souvenir',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/385-bave-bouftou',
#       'name': 'Bave de Bouftou'},
#      {'count': '5',
#       'link': '/fr/mmorpg/encyclopedie/ressources/7059-graine-pandouille',
#       'name': 'Graine de Pandouille'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8106',
#     'object_id': 8106,
#     'object_name': "Potion d'oubli de métier : Bricoleur",
#     'link': '/fr/mmorpg/encyclopedie/consommables/8106-potion-oubli-metier-bricoleur',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/consommables/793-potion-vieillesse',
#       'name': 'Potion de Vieillesse'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/consommables/7590-abreuvoir-frene',
#       'name': 'Abreuvoir en Frêne'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8883',
#     'object_id': 8883,
#     'object_name': 'Potion de Foyer de Guilde',
#     'link': '/fr/mmorpg/encyclopedie/consommables/8883-potion-foyer-guilde',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1770-bout-blop-coco',
#       'name': 'Bout de Blop Coco'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1773-bout-blop-reinette',
#       'name': 'Bout de Blop Reinette'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1775-bout-blop-griotte',
#       'name': 'Bout de Blop Griotte'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1777-bout-blop-indigo',
#       'name': 'Bout de Blop Indigo'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/consommables/2542-potion-foyer',
#       'name': 'Potion de Foyer'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/9035',
#     'object_id': 9035,
#     'object_name': "Potion d'enclos de Guilde",
#     'link': '/fr/mmorpg/encyclopedie/consommables/9035-potion-enclos-guilde',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1772-fleur-blop-coco',
#       'name': 'Fleur de Blop Coco'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1774-fleur-blop-reinette',
#       'name': 'Fleur de Blop Reinette'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1776-fleur-blop-griotte',
#       'name': 'Fleur de Blop Griotte'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1778-fleur-blop-indigo',
#       'name': 'Fleur de Blop Indigo'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/consommables/2542-potion-foyer',
#       'name': 'Potion de Foyer'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10031',
#     'object_id': 10031,
#     'object_name': 'Teinture Orange Sanguine',
#     'link': '/fr/mmorpg/encyclopedie/ressources/10031-teinture-orange-sanguine',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/838-sang-oni',
#       'name': "Sang d'Oni"},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1686-teinture-magique-rougeur',
#       'name': 'Teinture Magique de Rougeur'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1689-teinture-magique-orange',
#       'name': 'Teinture Magique Orange'},
#      {'count': '5',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1805-sardine-brillante',
#       'name': 'Sardine Brillante'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10208',
#     'object_id': 10208,
#     'object_name': 'Elixir Pandawa',
#     'link': '/fr/mmorpg/encyclopedie/consommables/10208-elixir-pandawa',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/398-fruit-palme',
#       'name': 'Fruit de Palme'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/428-fleur-chanvre',
#       'name': 'Fleur de Chanvre'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1734-cerise',
#       'name': 'Cerise'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1845-truite-videe',
#       'name': 'Truite vidée'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1894-poil-sanglier-plaines',
#       'name': 'Poil de Sanglier des Plaines'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10209',
#     'object_id': 10209,
#     'object_name': 'Elixir Sacrieur',
#     'link': '/fr/mmorpg/encyclopedie/consommables/10209-elixir-sacrieur',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/398-fruit-palme',
#       'name': 'Fruit de Palme'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/428-fleur-chanvre',
#       'name': 'Fleur de Chanvre'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/761-poils-souris',
#       'name': 'Poils de souris'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1734-cerise',
#       'name': 'Cerise'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1845-truite-videe',
#       'name': 'Truite vidée'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10210',
#     'object_id': 10210,
#     'object_name': 'Elixir Eniripsa',
#     'link': '/fr/mmorpg/encyclopedie/consommables/10210-elixir-eniripsa',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/398-fruit-palme',
#       'name': 'Fruit de Palme'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/428-fleur-chanvre',
#       'name': 'Fleur de Chanvre'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1734-cerise',
#       'name': 'Cerise'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1845-truite-videe',
#       'name': 'Truite vidée'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/17126-tranche-tikokoko',
#       'name': 'Tranche de Tikokoko'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10211',
#     'object_id': 10211,
#     'object_name': 'Elixir Sadida',
#     'link': '/fr/mmorpg/encyclopedie/consommables/10211-elixir-sadida',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/305-dent-wabbit',
#       'name': 'Dent de Wabbit'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/398-fruit-palme',
#       'name': 'Fruit de Palme'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/428-fleur-chanvre',
#       'name': 'Fleur de Chanvre'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1734-cerise',
#       'name': 'Cerise'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1845-truite-videe',
#       'name': 'Truite vidée'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10212',
#     'object_id': 10212,
#     'object_name': 'Elixir Crâ',
#     'link': '/fr/mmorpg/encyclopedie/consommables/10212-elixir-cra',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/398-fruit-palme',
#       'name': 'Fruit de Palme'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/428-fleur-chanvre',
#       'name': 'Fleur de Chanvre'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1734-cerise',
#       'name': 'Cerise'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1845-truite-videe',
#       'name': 'Truite vidée'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/8680-ecaille-poisseuse',
#       'name': 'Écaille poisseuse'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10213',
#     'object_id': 10213,
#     'object_name': 'Elixir Iop',
#     'link': '/fr/mmorpg/encyclopedie/consommables/10213-elixir-iop',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/383-corne-bouftou',
#       'name': 'Corne de Bouftou'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/398-fruit-palme',
#       'name': 'Fruit de Palme'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/428-fleur-chanvre',
#       'name': 'Fleur de Chanvre'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1734-cerise',
#       'name': 'Cerise'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1845-truite-videe',
#       'name': 'Truite vidée'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10214',
#     'object_id': 10214,
#     'object_name': 'Elixir Ecaflip',
#     'link': '/fr/mmorpg/encyclopedie/consommables/10214-elixir-ecaflip',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/398-fruit-palme',
#       'name': 'Fruit de Palme'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/428-fleur-chanvre',
#       'name': 'Fleur de Chanvre'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1734-cerise',
#       'name': 'Cerise'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1736-citron',
#       'name': 'Citron'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1845-truite-videe',
#       'name': 'Truite vidée'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10215',
#     'object_id': 10215,
#     'object_name': 'Elixir Xélor',
#     'link': '/fr/mmorpg/encyclopedie/consommables/10215-elixir-xelor',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/398-fruit-palme',
#       'name': 'Fruit de Palme'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/428-fleur-chanvre',
#       'name': 'Fleur de Chanvre'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1734-cerise',
#       'name': 'Cerise'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1845-truite-videe',
#       'name': 'Truite vidée'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1975-oignon',
#       'name': 'Oignon'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10216',
#     'object_id': 10216,
#     'object_name': 'Elixir Féca',
#     'link': '/fr/mmorpg/encyclopedie/consommables/10216-elixir-feca',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/309-petale-rose-demoniaque',
#       'name': 'Pétale de Rose Démoniaque'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/398-fruit-palme',
#       'name': 'Fruit de Palme'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/428-fleur-chanvre',
#       'name': 'Fleur de Chanvre'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1734-cerise',
#       'name': 'Cerise'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1845-truite-videe',
#       'name': 'Truite vidée'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10217',
#     'object_id': 10217,
#     'object_name': 'Elixir Enutrof',
#     'link': '/fr/mmorpg/encyclopedie/consommables/10217-elixir-enutrof',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/398-fruit-palme',
#       'name': 'Fruit de Palme'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/417-boue-boo',
#       'name': 'Boue du Boo'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/428-fleur-chanvre',
#       'name': 'Fleur de Chanvre'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1734-cerise',
#       'name': 'Cerise'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1845-truite-videe',
#       'name': 'Truite vidée'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10218',
#     'object_id': 10218,
#     'object_name': 'Elixir Osamodas',
#     'link': '/fr/mmorpg/encyclopedie/consommables/10218-elixir-osamodas',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/398-fruit-palme',
#       'name': 'Fruit de Palme'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/428-fleur-chanvre',
#       'name': 'Fleur de Chanvre'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1734-cerise',
#       'name': 'Cerise'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1845-truite-videe',
#       'name': 'Truite vidée'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/2336-crane-chafer',
#       'name': 'Crâne de Chafer'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10219',
#     'object_id': 10219,
#     'object_name': 'Elixir Sram',
#     'link': '/fr/mmorpg/encyclopedie/consommables/10219-elixir-sram',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/398-fruit-palme',
#       'name': 'Fruit de Palme'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/428-fleur-chanvre',
#       'name': 'Fleur de Chanvre'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1734-cerise',
#       'name': 'Cerise'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1845-truite-videe',
#       'name': 'Truite vidée'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/2322-crocs-rats',
#       'name': 'Crocs de Rats'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10669',
#     'object_id': 10669,
#     'object_name': 'Potion de crapaud-mufle',
#     'link': '/fr/mmorpg/encyclopedie/consommables/10669-potion-crapaud-mufle',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/362-peau-larve-bleue',
#       'name': 'Peau de Larve Bleue'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/367-oeuf-tofu',
#       'name': 'Oeuf de Tofu'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/385-bave-bouftou',
#       'name': 'Bave de Bouftou'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10673',
#     'object_id': 10673,
#     'object_name': 'Potion de HmmMmm',
#     'link': '/fr/mmorpg/encyclopedie/consommables/10673-potion-hmmmmm',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/363-peau-larve-orange',
#       'name': 'Peau de Larve Orange'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/365-patte-arakne',
#       'name': "Patte d'Arakne"},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/385-bave-bouftou',
#       'name': 'Bave de Bouftou'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/417-boue-boo',
#       'name': 'Boue du Boo'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10715',
#     'object_id': 10715,
#     'object_name': 'Poudre de Créatoune',
#     'link': '/fr/mmorpg/encyclopedie/ressources/10715-poudre-creatoune',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': [{'count': '5',
#       'link': '/fr/mmorpg/encyclopedie/ressources/380-feuille-menthe-sauvage',
#       'name': 'Feuille de Menthe Sauvage'},
#      {'count': '5',
#       'link': '/fr/mmorpg/encyclopedie/ressources/519-poudre-perlinpainpain',
#       'name': 'Poudre de Perlinpainpain'},
#      {'count': '5',
#       'link': '/fr/mmorpg/encyclopedie/ressources/534-farine-malt',
#       'name': 'Farine de Malt'},
#      {'count': '5',
#       'link': '/fr/mmorpg/encyclopedie/ressources/2008-museau-conserve',
#       'name': 'Museau Conservé'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10750',
#     'object_id': 10750,
#     'object_name': "Potion d'Amélioration d'Atouin",
#     'link': '/fr/mmorpg/encyclopedie/objets/10750-potion-amelioration-atouin',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10751',
#     'object_id': 10751,
#     'object_name': "Potion d'Amélioration de Bébé Pandawa",
#     'link': '/fr/mmorpg/encyclopedie/objets/10751-potion-amelioration-bebe-pandawa',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10752',
#     'object_id': 10752,
#     'object_name': "Potion d'Amélioration de Bilby",
#     'link': '/fr/mmorpg/encyclopedie/objets/10752-potion-amelioration-bilby',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10753',
#     'object_id': 10753,
#     'object_name': "Potion d'Amélioration de Bwak",
#     'link': '/fr/mmorpg/encyclopedie/objets/10753-potion-amelioration-bwak',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10754',
#     'object_id': 10754,
#     'object_name': "Potion d'Amélioration de Bworky",
#     'link': '/fr/mmorpg/encyclopedie/objets/10754-potion-amelioration-bworky',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10755',
#     'object_id': 10755,
#     'object_name': "Potion d'Amélioration de Chacha",
#     'link': '/fr/mmorpg/encyclopedie/objets/10755-potion-amelioration-chacha',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10756',
#     'object_id': 10756,
#     'object_name': "Potion d'Amélioration de Chacha Angora",
#     'link': '/fr/mmorpg/encyclopedie/objets/10756-potion-amelioration-chacha-angora',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10757',
#     'object_id': 10757,
#     'object_name': "Potion d'Amélioration de Chacha Tigré",
#     'link': '/fr/mmorpg/encyclopedie/objets/10757-potion-amelioration-chacha-tigre',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10758',
#     'object_id': 10758,
#     'object_name': "Potion d'Amélioration de Crocodaille",
#     'link': '/fr/mmorpg/encyclopedie/objets/10758-potion-amelioration-crocodaille',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10759',
#     'object_id': 10759,
#     'object_name': "Potion d'Amélioration d'Ecureuil Chenapan",
#     'link': '/fr/mmorpg/encyclopedie/objets/10759-potion-amelioration-ecureuil-chenapan',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10760',
#     'object_id': 10760,
#     'object_name': "Potion d'Amélioration de Fëanor",
#     'link': '/fr/mmorpg/encyclopedie/objets/10760-potion-amelioration-feanor',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10761',
#     'object_id': 10761,
#     'object_name': "Potion d'Amélioration de Koalak Sanguin",
#     'link': '/fr/mmorpg/encyclopedie/objets/10761-potion-amelioration-koalak-sanguin',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10762',
#     'object_id': 10762,
#     'object_name': "Potion d'Amélioration de Kouin-Kouin",
#     'link': '/fr/mmorpg/encyclopedie/objets/10762-potion-amelioration-kouin-kouin',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10763',
#     'object_id': 10763,
#     'object_name': "Potion d'Amélioration de Léopardo",
#     'link': '/fr/mmorpg/encyclopedie/objets/10763-potion-amelioration-leopardo',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10764',
#     'object_id': 10764,
#     'object_name': "Potion d'Amélioration de Mini Wa",
#     'link': '/fr/mmorpg/encyclopedie/objets/10764-potion-amelioration-mini-wa',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10765',
#     'object_id': 10765,
#     'object_name': "Potion d'Amélioration de Nomoon",
#     'link': '/fr/mmorpg/encyclopedie/objets/10765-potion-amelioration-nomoon',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10766',
#     'object_id': 10766,
#     'object_name': "Potion d'Amélioration de Péki",
#     'link': '/fr/mmorpg/encyclopedie/objets/10766-potion-amelioration-peki',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10767',
#     'object_id': 10767,
#     'object_name': "Potion d'Amélioration de Petit Chacha Blanc",
#     'link': '/fr/mmorpg/encyclopedie/objets/10767-potion-amelioration-petit-chacha-blanc',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10768',
#     'object_id': 10768,
#     'object_name': "Potion d'Amélioration de Petit Chienchien Noir",
#     'link': '/fr/mmorpg/encyclopedie/objets/10768-potion-amelioration-petit-chienchien-noir',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10769',
#     'object_id': 10769,
#     'object_name': "Potion d'Amélioration de Pioute",
#     'link': '/fr/mmorpg/encyclopedie/objets/10769-potion-amelioration-pioute',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10770',
#     'object_id': 10770,
#     'object_name': "Potion d'Amélioration de Ross",
#     'link': '/fr/mmorpg/encyclopedie/objets/10770-potion-amelioration-ross',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10771',
#     'object_id': 10771,
#     'object_name': "Potion d'Amélioration de Vilain Petit Corbac",
#     'link': '/fr/mmorpg/encyclopedie/objets/10771-potion-amelioration-vilain-petit-corbac',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10772',
#     'object_id': 10772,
#     'object_name': "Potion d'Amélioration de Wabbit",
#     'link': '/fr/mmorpg/encyclopedie/objets/10772-potion-amelioration-wabbit',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10773',
#     'object_id': 10773,
#     'object_name': "Potion d'Amélioration de Walk",
#     'link': '/fr/mmorpg/encyclopedie/objets/10773-potion-amelioration-walk',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10774',
#     'object_id': 10774,
#     'object_name': "Potion d'Amélioration de Willy le Relou",
#     'link': '/fr/mmorpg/encyclopedie/objets/10774-potion-amelioration-willy-relou',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10776',
#     'object_id': 10776,
#     'object_name': "Potion d'Amélioration de Miniminotot",
#     'link': '/fr/mmorpg/encyclopedie/objets/10776-potion-amelioration-miniminotot',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10777',
#     'object_id': 10777,
#     'object_name': "Potion d'Amélioration de Tiwabbit Kiafin",
#     'link': '/fr/mmorpg/encyclopedie/objets/10777-potion-amelioration-tiwabbit-kiafin',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10778',
#     'object_id': 10778,
#     'object_name': "Potion d'Amélioration de Chauffe-Souris",
#     'link': '/fr/mmorpg/encyclopedie/objets/10778-potion-amelioration-chauffe-souris',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10779',
#     'object_id': 10779,
#     'object_name': "Potion d'Amélioration de Dragoune Noire",
#     'link': '/fr/mmorpg/encyclopedie/objets/10779-potion-amelioration-dragoune-noire',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10780',
#     'object_id': 10780,
#     'object_name': "Potion d'Amélioration de Bouloute du Parrain",
#     'link': '/fr/mmorpg/encyclopedie/objets/10780-potion-amelioration-bouloute-parrain',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10781',
#     'object_id': 10781,
#     'object_name': "Potion d'Amélioration de Gelutin",
#     'link': '/fr/mmorpg/encyclopedie/objets/10781-potion-amelioration-gelutin',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10782',
#     'object_id': 10782,
#     'object_name': "Potion d'Amélioration de Shushu de Rushu",
#     'link': '/fr/mmorpg/encyclopedie/objets/10782-potion-amelioration-shushu-rushu',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10783',
#     'object_id': 10783,
#     'object_name': "Potion d'Amélioration de Vampyrette",
#     'link': '/fr/mmorpg/encyclopedie/objets/10783-potion-amelioration-vampyrette',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10809',
#     'object_id': 10809,
#     'object_name': "Potion d'Amélioration de Dragoune Dorée",
#     'link': '/fr/mmorpg/encyclopedie/objets/10809-potion-amelioration-dragoune-doree',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10811',
#     'object_id': 10811,
#     'object_name': "Potion d'Amélioration de Goultus",
#     'link': '/fr/mmorpg/encyclopedie/objets/10811-potion-amelioration-goultus',
#     'level': 1,
#     'profession': 'Alchimiste'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/10827',
#     'object_id': 10827,
#     'object_name': 'Potion de soin larvesque',
#     'link': '/fr/mmorpg/encyclopedie/consommables/10827-potion-soin-larvesque',
#     'level': 1,
#     'profession': 'Alchimiste',
#     'ingredients': []}]},
#  'Bijoutier': {'link': '/fr/mmorpg/encyclopedie/metiers/16-bijoutier',
#   'recipes': [{'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/82',
#     'object_id': 82,
#     'object_name': 'Amulette du Loup',
#     'link': '/fr/mmorpg/encyclopedie/equipements/82-amulette-loup',
#     'level': 2,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/303-bois-frene',
#       'name': 'Bois de Frêne'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/442-bronze',
#       'name': 'Bronze'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/786',
#     'object_id': 786,
#     'object_name': 'Pendentif du Hibou Chétif',
#     'link': '/fr/mmorpg/encyclopedie/equipements/786-pendentif-hibou-chetif',
#     'level': 2,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/303-bois-frene',
#       'name': 'Bois de Frêne'},
#      {'count': '3',
#       'link': '/fr/mmorpg/encyclopedie/ressources/442-bronze',
#       'name': 'Bronze'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/787',
#     'object_id': 787,
#     'object_name': 'Anneau Rexik',
#     'link': '/fr/mmorpg/encyclopedie/equipements/787-anneau-rexik',
#     'level': 2,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/441-cuivre',
#       'name': 'Cuivre'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/473-bois-chataignier',
#       'name': 'Bois de Châtaignier'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/851',
#     'object_id': 851,
#     'object_name': 'Anneau Vitalesque',
#     'link': '/fr/mmorpg/encyclopedie/equipements/851-anneau-vitalesque',
#     'level': 2,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/312-fer',
#       'name': 'Fer'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/598-greu-vette',
#       'name': 'Greu-Vette'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/849',
#     'object_id': 849,
#     'object_name': 'Anneau Forcesque',
#     'link': '/fr/mmorpg/encyclopedie/equipements/849-anneau-forcesque',
#     'level': 3,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/312-fer',
#       'name': 'Fer'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1987-viande-oiseau-conservee',
#       'name': "Viande d'Oiseau Conservée"}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/850',
#     'object_id': 850,
#     'object_name': 'Anneau Agilesque',
#     'link': '/fr/mmorpg/encyclopedie/equipements/850-anneau-agilesque',
#     'level': 3,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/312-fer',
#       'name': 'Fer'},
#      {'count': '5',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1736-citron',
#       'name': 'Citron'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8538',
#     'object_id': 8538,
#     'object_name': "Le S'Mesme",
#     'link': '/fr/mmorpg/encyclopedie/equipements/8538-mesme',
#     'level': 3,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '3',
#       'link': '/fr/mmorpg/encyclopedie/ressources/289-ble',
#       'name': 'Blé'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/303-bois-frene',
#       'name': 'Bois de Frêne'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/768',
#     'object_id': 768,
#     'object_name': 'Camaïneux',
#     'link': '/fr/mmorpg/encyclopedie/equipements/768-camaineux',
#     'level': 4,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/312-fer',
#       'name': 'Fer'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/421-fleur-lin',
#       'name': 'Fleur de Lin'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/8537',
#     'object_id': 8537,
#     'object_name': 'Le Plussain',
#     'link': '/fr/mmorpg/encyclopedie/equipements/8537-plussain',
#     'level': 5,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/289-ble',
#       'name': 'Blé'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/303-bois-frene',
#       'name': 'Bois de Frêne'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/74',
#     'object_id': 74,
#     'object_name': "Petite Amulette de l'Ours",
#     'link': '/fr/mmorpg/encyclopedie/equipements/74-petite-amulette-ours',
#     'level': 6,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/421-fleur-lin',
#       'name': 'Fleur de Lin'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/473-bois-chataignier',
#       'name': 'Bois de Châtaignier'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/767',
#     'object_id': 767,
#     'object_name': 'Gantie Royal',
#     'link': '/fr/mmorpg/encyclopedie/equipements/767-gantie-royal',
#     'level': 6,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '3',
#       'link': '/fr/mmorpg/encyclopedie/ressources/289-ble',
#       'name': 'Blé'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/312-fer',
#       'name': 'Fer'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2475',
#     'object_id': 2475,
#     'object_name': "Anneau de l'Aventurier",
#     'link': '/fr/mmorpg/encyclopedie/equipements/2475-anneau-aventurier',
#     'level': 7,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '3',
#       'link': '/fr/mmorpg/encyclopedie/ressources/307-ailes-moskito',
#       'name': 'Ailes de Moskito'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1896-viande-oiseau',
#       'name': "Viande d'Oiseau"}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/101',
#     'object_id': 101,
#     'object_name': 'Anneau de Sagesse',
#     'link': '/fr/mmorpg/encyclopedie/equipements/101-anneau-sagesse',
#     'level': 8,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/312-fer',
#       'name': 'Fer'},
#      {'count': '3',
#       'link': '/fr/mmorpg/encyclopedie/ressources/442-bronze',
#       'name': 'Bronze'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/280',
#     'object_id': 280,
#     'object_name': "Collier de l'Arc en Ciel",
#     'link': '/fr/mmorpg/encyclopedie/equipements/280-collier-arc-ciel',
#     'level': 8,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/289-ble',
#       'name': 'Blé'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/473-bois-chataignier',
#       'name': 'Bois de Châtaignier'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/766',
#     'object_id': 766,
#     'object_name': 'Koliet Aclou',
#     'link': '/fr/mmorpg/encyclopedie/equipements/766-koliet-aclou',
#     'level': 8,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '5',
#       'link': '/fr/mmorpg/encyclopedie/ressources/303-bois-frene',
#       'name': 'Bois de Frêne'},
#      {'count': '5',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1734-cerise',
#       'name': 'Cerise'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/2478',
#     'object_id': 2478,
#     'object_name': "Amulette de l'Aventurier",
#     'link': '/fr/mmorpg/encyclopedie/equipements/2478-amulette-aventurier',
#     'level': 8,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '5',
#       'link': '/fr/mmorpg/encyclopedie/ressources/289-ble',
#       'name': 'Blé'},
#      {'count': '5',
#       'link': '/fr/mmorpg/encyclopedie/ressources/365-patte-arakne',
#       'name': "Patte d'Arakne"}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/279',
#     'object_id': 279,
#     'object_name': 'La Larme du Bouftou',
#     'link': '/fr/mmorpg/encyclopedie/equipements/279-larme-bouftou',
#     'level': 9,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/441-cuivre',
#       'name': 'Cuivre'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1782-goujon',
#       'name': 'Goujon'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/324',
#     'object_id': 324,
#     'object_name': 'Amulette de Krokette',
#     'link': '/fr/mmorpg/encyclopedie/equipements/324-amulette-krokette',
#     'level': 9,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/312-fer',
#       'name': 'Fer'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1896-viande-oiseau',
#       'name': "Viande d'Oiseau"}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/110',
#     'object_id': 110,
#     'object_name': 'Anneau de Chance',
#     'link': '/fr/mmorpg/encyclopedie/equipements/110-anneau-chance',
#     'level': 10,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/441-cuivre',
#       'name': 'Cuivre'},
#      {'count': '3',
#       'link': '/fr/mmorpg/encyclopedie/ressources/442-bronze',
#       'name': 'Bronze'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/119',
#     'object_id': 119,
#     'object_name': "Anneau d'Agilité",
#     'link': '/fr/mmorpg/encyclopedie/equipements/119-anneau-agilite',
#     'level': 10,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/312-fer',
#       'name': 'Fer'},
#      {'count': '3',
#       'link': '/fr/mmorpg/encyclopedie/ressources/441-cuivre',
#       'name': 'Cuivre'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/785',
#     'object_id': 785,
#     'object_name': 'Anneau Fortifiant',
#     'link': '/fr/mmorpg/encyclopedie/equipements/785-anneau-fortifiant',
#     'level': 10,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '3',
#       'link': '/fr/mmorpg/encyclopedie/ressources/303-bois-frene',
#       'name': 'Bois de Frêne'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/312-fer',
#       'name': 'Fer'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/856',
#     'object_id': 856,
#     'object_name': 'Grenouillette',
#     'link': '/fr/mmorpg/encyclopedie/equipements/856-grenouillette',
#     'level': 10,
#     'profession': 'Bijoutier',
#     'ingredients': [{'count': '3',
#       'link': '/fr/mmorpg/encyclopedie/ressources/303-bois-frene',
#       'name': 'Bois de Frêne'},
#      {'count': '3',
#       'link': '/fr/mmorpg/encyclopedie/ressources/1782-goujon',
#       'name': 'Goujon'}]},
# ...
#      {'count': '37',
#       'link': '/fr/mmorpg/encyclopedie/ressources/17606-tete-lance-fangshu',
#       'name': 'Tête de lance de Fangshu'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/14055',
#     'object_id': 14055,
#     'object_name': 'Bêche Asse',
#     'link': '/fr/mmorpg/encyclopedie/armes/14055-beche-asse',
#     'level': 197,
#     'profession': 'Forgeur de Pelles',
#     'ingredients': [{'count': '38',
#       'link': '/fr/mmorpg/encyclopedie/ressources/11938-cuir-glouragan',
#       'name': 'Cuir de Glouragan'},
#      {'count': '3',
#       'link': '/fr/mmorpg/encyclopedie/ressources/12740-galet-brasillant',
#       'name': 'Galet brasillant'},
#      {'count': '22',
#       'link': '/fr/mmorpg/encyclopedie/ressources/13925-sang-armutin',
#       'name': "Sang d'Armutin"},
#      {'count': '36',
#       'link': '/fr/mmorpg/encyclopedie/ressources/13931-incus-verglasseur',
#       'name': 'Incus de Verglasseur'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/14141-racine-cristalline',
#       'name': 'Racine cristalline'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/15575-essence-bworker',
#       'name': 'Essence de Bworker'},
#      {'count': '24',
#       'link': '/fr/mmorpg/encyclopedie/ressources/17052-graisse-archillusion',
#       'name': "Graisse d'Archillusion"},
#      {'count': '37',
#       'link': '/fr/mmorpg/encyclopedie/ressources/17608-lame-brisee-lichangoro',
#       'name': 'Lame brisée de Lichangoro'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/14135',
#     'object_id': 14135,
#     'object_name': 'Pelle Vice',
#     'link': '/fr/mmorpg/encyclopedie/armes/14135-pelle-vice',
#     'level': 199,
#     'profession': 'Forgeur de Pelles',
#     'ingredients': [{'count': '4',
#       'link': '/fr/mmorpg/encyclopedie/ressources/11518-fragment-gele',
#       'name': 'Fragment gelé'},
#      {'count': '36',
#       'link': '/fr/mmorpg/encyclopedie/ressources/11527-peau-ouilleur',
#       'name': "Peau d'Ouilleur"},
#      {'count': '28',
#       'link': '/fr/mmorpg/encyclopedie/ressources/11885-lamelle-fongique',
#       'name': 'Lamelle Fongique'},
#      {'count': '40',
#       'link': '/fr/mmorpg/encyclopedie/ressources/11929-queue-blerom',
#       'name': 'Queue de Blérom'},
#      {'count': '19',
#       'link': '/fr/mmorpg/encyclopedie/ressources/12728-ardonite',
#       'name': 'Ardonite'},
#      {'count': '3',
#       'link': '/fr/mmorpg/encyclopedie/ressources/12740-galet-brasillant',
#       'name': 'Galet brasillant'},
#      {'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/16201-essence-founoroshi',
#       'name': 'Essence de Founoroshi'},
#      {'count': '30',
#       'link': '/fr/mmorpg/encyclopedie/ressources/17058-estomac-bwork',
#       'name': 'Estomac de Bwork'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/15631',
#     'object_id': 15631,
#     'object_name': 'Pelle de la Corporation',
#     'link': '/fr/mmorpg/encyclopedie/armes/15631-pelle-corporation',
#     'level': 200,
#     'profession': 'Forgeur de Pelles',
#     'ingredients': [{'count': '3',
#       'link': '/fr/mmorpg/encyclopedie/ressources/12740-galet-brasillant',
#       'name': 'Galet brasillant'},
#      {'count': '8',
#       'link': '/fr/mmorpg/encyclopedie/ressources/13156-oeil-ougah',
#       'name': "Oeil d'Ougah"},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/13157-ongle-bworker',
#       'name': 'Ongle du Bworker'},
#      {'count': '34',
#       'link': '/fr/mmorpg/encyclopedie/ressources/13925-sang-armutin',
#       'name': "Sang d'Armutin"},
#      {'count': '62',
#       'link': '/fr/mmorpg/encyclopedie/ressources/13933-stapes-frimar',
#       'name': 'Stapes de Frimar'},
#      {'count': '8',
#       'link': '/fr/mmorpg/encyclopedie/ressources/13935-poil-aisselle-missiz-frizz',
#       'name': "Poil d'aisselle de Missiz Frizz"},
#      {'count': '12',
#       'link': '/fr/mmorpg/encyclopedie/ressources/15259-tourmaline',
#       'name': 'Tourmaline'},
#      {'count': '31',
#       'link': '/fr/mmorpg/encyclopedie/ressources/17586-epine-plantala',
#       'name': 'Epine de Plantala'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/16031',
#     'object_id': 16031,
#     'object_name': 'Harpelle',
#     'link': '/fr/mmorpg/encyclopedie/armes/16031-harpelle',
#     'level': 200,
#     'profession': 'Forgeur de Pelles',
#     'ingredients': [{'count': '6',
#       'link': '/fr/mmorpg/encyclopedie/ressources/11516-etoffe-givree',
#       'name': 'Etoffe givrée'},
#      {'count': '34',
#       'link': '/fr/mmorpg/encyclopedie/ressources/13975-astragale-brikolereux',
#       'name': 'Astragale de Brikoléreux '},
#      {'count': '12',
#       'link': '/fr/mmorpg/encyclopedie/ressources/15259-tourmaline',
#       'name': 'Tourmaline'},
#      {'count': '60',
#       'link': '/fr/mmorpg/encyclopedie/ressources/15748-orbe-irise',
#       'name': 'Orbe irisé'},
#      {'count': '25',
#       'link': '/fr/mmorpg/encyclopedie/ressources/15750-andesite',
#       'name': 'Andésite'},
#      {'count': '8',
#       'link': '/fr/mmorpg/encyclopedie/ressources/17580-bourgeon-explosif-damadrya',
#       'name': 'Bourgeon explosif de Damadrya'},
#      {'count': '63',
#       'link': '/fr/mmorpg/encyclopedie/ressources/17582-tige-bambouto',
#       'name': 'Tige de Bambouto'},
#      {'count': '56',
#       'link': '/fr/mmorpg/encyclopedie/ressources/17600-bracelet-ino-naru',
#       'name': "Bracelet d'Ino-Naru"}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/19185',
#     'object_id': 19185,
#     'object_name': 'Serpe Aigrie',
#     'link': '/fr/mmorpg/encyclopedie/armes/19185-serpe-aigrie',
#     'level': 200,
#     'profession': 'Forgeur de Pelles',
#     'ingredients': []}]},
#  'Joaillomage': {'link': '/fr/mmorpg/encyclopedie/metiers/63-joaillomage',
#   'recipes': []},
#  'Mineur': {'link': '/fr/mmorpg/encyclopedie/metiers/24-mineur',
#   'recipes': [{'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7026',
#     'object_id': 7026,
#     'object_name': 'Aigue-Marine',
#     'link': '/fr/mmorpg/encyclopedie/ressources/7026-aigue-marine',
#     'level': 60,
#     'profession': 'Mineur',
#     'ingredients': [{'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/311-eau',
#       'name': 'Eau'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/7023-pierre-aigue-marine',
#       'name': "Pierre d'Aigue-Marine"}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7027',
#     'object_id': 7027,
#     'object_name': 'Topaze',
#     'link': '/fr/mmorpg/encyclopedie/ressources/7027-topaze',
#     'level': 70,
#     'profession': 'Mineur',
#     'ingredients': [{'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/311-eau',
#       'name': 'Eau'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/7024-pierre-topaze',
#       'name': 'Pierre de Topaze'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6457',
#     'object_id': 6457,
#     'object_name': 'Kriptonite',
#     'link': '/fr/mmorpg/encyclopedie/ressources/6457-kriptonite',
#     'level': 80,
#     'profession': 'Mineur',
#     'ingredients': [{'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/312-fer',
#       'name': 'Fer'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/350-argent',
#       'name': 'Argent'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/441-cuivre',
#       'name': 'Cuivre'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/442-bronze',
#       'name': 'Bronze'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/443-kobalte',
#       'name': 'Kobalte'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/444-etain',
#       'name': 'Etain'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/445-manganese',
#       'name': 'Manganèse'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7028',
#     'object_id': 7028,
#     'object_name': 'Agathe',
#     'link': '/fr/mmorpg/encyclopedie/ressources/7028-agathe',
#     'level': 80,
#     'profession': 'Mineur',
#     'ingredients': [{'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/311-eau',
#       'name': 'Eau'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/7025-pierre-agathe',
#       'name': "Pierre d'Agathe"}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6458',
#     'object_id': 6458,
#     'object_name': 'Kobalite',
#     'link': '/fr/mmorpg/encyclopedie/ressources/6458-kobalite',
#     'level': 100,
#     'profession': 'Mineur',
#     'ingredients': [{'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/312-fer',
#       'name': 'Fer'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/350-argent',
#       'name': 'Argent'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/441-cuivre',
#       'name': 'Cuivre'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/442-bronze',
#       'name': 'Bronze'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/443-kobalte',
#       'name': 'Kobalte'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/444-etain',
#       'name': 'Etain'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/445-manganese',
#       'name': 'Manganèse'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/446-bauxite',
#       'name': 'Bauxite'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7035',
#     'object_id': 7035,
#     'object_name': 'Pyrute',
#     'link': '/fr/mmorpg/encyclopedie/ressources/7035-pyrute',
#     'level': 100,
#     'profession': 'Mineur',
#     'ingredients': [{'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/350-argent',
#       'name': 'Argent'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/441-cuivre',
#       'name': 'Cuivre'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/442-bronze',
#       'name': 'Bronze'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/443-kobalte',
#       'name': 'Kobalte'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/444-etain',
#       'name': 'Etain'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/445-manganese',
#       'name': 'Manganèse'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/446-bauxite',
#       'name': 'Bauxite'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/7033-dolomite',
#       'name': 'Dolomite'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7036',
#     'object_id': 7036,
#     'object_name': 'Rutile',
#     'link': '/fr/mmorpg/encyclopedie/ressources/7036-rutile',
#     'level': 100,
#     'profession': 'Mineur',
#     'ingredients': [{'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/313-or',
#       'name': 'Or'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/350-argent',
#       'name': 'Argent'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/441-cuivre',
#       'name': 'Cuivre'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/442-bronze',
#       'name': 'Bronze'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/443-kobalte',
#       'name': 'Kobalte'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/444-etain',
#       'name': 'Etain'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/445-manganese',
#       'name': 'Manganèse'},
#      {'count': '10',
#       'link': '/fr/mmorpg/encyclopedie/ressources/7032-silicate',
#       'name': 'Silicate'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/11280',
#     'object_id': 11280,
#     'object_name': "Plaque d'acier",
#     'link': '/fr/mmorpg/encyclopedie/ressources/11280-plaque-acier',
#     'level': 100,
#     'profession': 'Mineur'},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/12728',
#     'object_id': 12728,
#     'object_name': 'Ardonite',
#     'link': '/fr/mmorpg/encyclopedie/ressources/12728-ardonite',
#     'level': 100,
#     'profession': 'Mineur',
#     'ingredients': []}]},
#  'Paysan': {'link': '/fr/mmorpg/encyclopedie/metiers/28-paysan',
#   'recipes': [{'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/587',
#     'object_id': 587,
#     'object_name': 'Farine Complète',
#     'link': '/fr/mmorpg/encyclopedie/ressources/587-farine-complete',
#     'level': 40,
#     'profession': 'Paysan',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/289-ble',
#       'name': 'Blé'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/400-orge',
#       'name': 'Orge'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/401-houblon',
#       'name': 'Houblon'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/532-seigle',
#       'name': 'Seigle'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/533-avoine',
#       'name': 'Avoine'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/7068',
#     'object_id': 7068,
#     'object_name': 'Farine de Riz',
#     'link': '/fr/mmorpg/encyclopedie/ressources/7068-farine-riz',
#     'level': 50,
#     'profession': 'Paysan',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/7018-riz',
#       'name': 'Riz'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/6672',
#     'object_id': 6672,
#     'object_name': 'Farine de Xavier le Boulanger',
#     'link': '/fr/mmorpg/encyclopedie/ressources/6672-farine-xavier-boulanger',
#     'level': 100,
#     'profession': 'Paysan',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/289-ble',
#       'name': 'Blé'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/400-orge',
#       'name': 'Orge'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/401-houblon',
#       'name': 'Houblon'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/405-malt',
#       'name': 'Malt'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/423-lin',
#       'name': 'Lin'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/425-chanvre',
#       'name': 'Chanvre'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/532-seigle',
#       'name': 'Seigle'},
#      {'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/533-avoine',
#       'name': 'Avoine'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/11194',
#     'object_id': 11194,
#     'object_name': 'Farine de Frostiz',
#     'link': '/fr/mmorpg/encyclopedie/ressources/11194-farine-frostiz',
#     'level': 100,
#     'profession': 'Paysan',
#     'ingredients': [{'count': '2',
#       'link': '/fr/mmorpg/encyclopedie/ressources/11109-frostiz',
#       'name': 'Frostiz'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/11199',
#     'object_id': 11199,
#     'object_name': 'Graine de Frostiz',
#     'link': '/fr/mmorpg/encyclopedie/ressources/11199-graine-frostiz',
#     'level': 100,
#     'profession': 'Paysan',
#     'ingredients': [{'count': '5',
#       'link': '/fr/mmorpg/encyclopedie/ressources/11109-frostiz',
#       'name': 'Frostiz'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/11497',
#     'object_id': 11497,
#     'object_name': 'Huile de Frostiz',
#     'link': '/fr/mmorpg/encyclopedie/ressources/11497-huile-frostiz',
#     'level': 100,
#     'profession': 'Paysan',
#     'ingredients': [{'count': '3',
#       'link': '/fr/mmorpg/encyclopedie/ressources/11109-frostiz',
#       'name': 'Frostiz'}]},
#    {'detail_url': '/fr/mmorpg/encyclopedie/objets/recette/11502',
#     'object_id': 11502,
#     'object_name': 'Farine de Frostiz soufflé',
#     'link': '/fr/mmorpg/encyclopedie/ressources/11502-farine-frostiz-souffle',
#     'level': 100,
#     'profession': 'Paysan',
#     'ingredients': [{'count': '1',
#       'link': '/fr/mmorpg/encyclopedie/ressources/11499-frostiz-souffle',
#       'name': 'Frostiz soufflé'}]}]}}

# %%
request_count = 0
list_404 = []
for [name, profession] in professions.items():
    
    print(name)
    recipes = profession["recipes"]
    recipe_fetch_headers = {
        "Accept"        :"*/*",
        "X-Requested-With": "XMLHttpRequest",
        "Referer"       :profession["link"] + "/recipes",
        "Sec-Fetch-Dest":"empty",
        "Sec-Fetch-Mode":"cors",
        "Sec-Fetch-Site":"same-origin",
        "User-Agent"    :"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:126.0) Gecko/20100101 Firefox/126.0"
    }

    request_count += len(recipes) 
    all_recipe_json = await query_all_pages([f"https://www.dofus-touch.com/fr/mmorpg/encyclopedie/objets/recette/" + str(r["object_id"]) for r in recipes], headers=recipe_fetch_headers)
    all_recipe_html = [json.loads(j) for j in all_recipe_json]

    recipe["ingredients"] = []

    for [recipe, html] in zip(recipes, all_recipe_html):
        # For some reason some recepy html are empty. Should probably tell ankama...
        if html == "":
            continue

        soup = BeautifulSoup(html, "html.parser")

        # We also have 404 errors on some object links. Ankama fix link plz
        if (soup.find("div", "ak-404")):
            list_404.append([recipe, soup])
            continue

        # This documennt is a grid of objects. First find the container of the grid
        grid_container = soup.find("div", "ak-content-list")

        # Now we can get all the items in the grid. They are all of the "ak-list-element" class
        ingredients_html = grid_container.find_all("div", "ak-list-element")

        ingredients = []

        for ingredient_html in ingredients_html:
            # The item count is embedded in a text in front of the content : e.g "10 x" contained in a "ak-front" element
            item_count_text = ingredient_html.find("div", "ak-front")
            item_count = re.match("(\d+) x", item_count_text.string.strip()).group(1)
            
            # Now go and get the item properties, they are all in a div under the item
            content = ingredient_html.find("div", "ak-content")

            ingredient = {}

            # Gather the data.
            ingredient["count"] = item_count
            ingredient["link"] = content.find("a").get("href")
            ingredient["name"] = content.find("span", "ak-linker").string
            ingredients.append(ingredient)

        recipe["ingredients"] = ingredients
        
    # Force a wait to avoid being blocked out of the website. Limit rate of cloudfront is 5 minutes, so we assume we need to wait that much
    # 500 is arbitrary, we can probably spam our way to a precise number but that should do for now
    if (request_count > 500):
        request_count = 0
        
        await asyncio.sleep(5 * 60 + 1)
# Out:
# Alchimiste
# Bijoutier
# Boucher
# Boulanger
# Bricoleur
# Bûcheron
# Chasseur
# Cordomage
# Cordonnier
# Costumage
# Façonneur
# Forgemage d'Epées
# Forgemage de Dagues
# Forgemage de Haches
# Forgemage de Marteaux
# Forgemage de Pelles
# Forgeur d'Epées
# Forgeur de Dagues
# Forgeur de Haches
# Forgeur de Marteaux
# Forgeur de Pelles
# Joaillomage
# Mineur
# Paysan

# %%
recipes_df = pd.DataFrame(all_recipes).set_index("object_id")
recipes_df.to_json("recipes.json")
recipes_df
# Out:
#                                              detail_url  \
# object_id
# 1642        /fr/mmorpg/encyclopedie/objets/recette/1642
# 1643        /fr/mmorpg/encyclopedie/objets/recette/1643
# 1644        /fr/mmorpg/encyclopedie/objets/recette/1644
# 1645        /fr/mmorpg/encyclopedie/objets/recette/1645
# 1646        /fr/mmorpg/encyclopedie/objets/recette/1646
# ...                                                 ...
# 6672        /fr/mmorpg/encyclopedie/objets/recette/6672
# 11194      /fr/mmorpg/encyclopedie/objets/recette/11194
# 11199      /fr/mmorpg/encyclopedie/objets/recette/11199
# 11497      /fr/mmorpg/encyclopedie/objets/recette/11497
# 11502      /fr/mmorpg/encyclopedie/objets/recette/11502
#
#                                                 object_name  \
# object_id
# 1642         Potion d'oubli de métier : Forgemage de Dagues
# 1643         Potion d'oubli de métier : Forgemage de Haches
# 1644       Potion d'oubli de métier : Forgemage de Marteaux
# 1645           Potion d'oubli de métier : Forgemage d'Epées
# 1646         Potion d'oubli de métier : Forgemage de Pelles
# ...                                                     ...
# 6672                          Farine de Xavier le Boulanger
# 11194                                     Farine de Frostiz
# 11199                                     Graine de Frostiz
# 11497                                      Huile de Frostiz
# 11502                             Farine de Frostiz soufflé
#
#                                                         link  level  \
# object_id
# 1642       /fr/mmorpg/encyclopedie/consommables/1642-poti...      1
# 1643       /fr/mmorpg/encyclopedie/consommables/1643-poti...      1
# 1644       /fr/mmorpg/encyclopedie/consommables/1644-poti...      1
# 1645       /fr/mmorpg/encyclopedie/consommables/1645-poti...      1
# 1646       /fr/mmorpg/encyclopedie/consommables/1646-poti...      1
# ...                                                      ...    ...
# 6672       /fr/mmorpg/encyclopedie/ressources/6672-farine...    100
# 11194      /fr/mmorpg/encyclopedie/ressources/11194-farin...    100
# 11199      /fr/mmorpg/encyclopedie/ressources/11199-grain...    100
# 11497      /fr/mmorpg/encyclopedie/ressources/11497-huile...    100
# 11502      /fr/mmorpg/encyclopedie/ressources/11502-farin...    100
#
#            profession                                        ingredients
# object_id
# 1642       Alchimiste  [{'count': '1', 'link': '/fr/mmorpg/encycloped...
# 1643       Alchimiste  [{'count': '2', 'link': '/fr/mmorpg/encycloped...
# 1644       Alchimiste  [{'count': '2', 'link': '/fr/mmorpg/encycloped...
# 1645       Alchimiste  [{'count': '1', 'link': '/fr/mmorpg/encycloped...
# 1646       Alchimiste  [{'count': '1', 'link': '/fr/mmorpg/encycloped...
# ...               ...                                                ...
# 6672           Paysan  [{'count': '2', 'link': '/fr/mmorpg/encycloped...
# 11194          Paysan  [{'count': '2', 'link': '/fr/mmorpg/encycloped...
# 11199          Paysan  [{'count': '5', 'link': '/fr/mmorpg/encycloped...
# 11497          Paysan  [{'count': '3', 'link': '/fr/mmorpg/encycloped...
# 11502          Paysan  [{'count': '1', 'link': '/fr/mmorpg/encycloped...
#
# [1839 rows x 6 columns]

# %%
professions_df = pd.DataFrame(professions).T
professions_df.to_json("professions.json")
professions_df
# Out:
#                                                                     link  \
# Alchimiste                 /fr/mmorpg/encyclopedie/metiers/26-alchimiste
# Bijoutier                   /fr/mmorpg/encyclopedie/metiers/16-bijoutier
# Boucher                       /fr/mmorpg/encyclopedie/metiers/56-boucher
# Boulanger                   /fr/mmorpg/encyclopedie/metiers/25-boulanger
# Bricoleur                   /fr/mmorpg/encyclopedie/metiers/65-bricoleur
# Bûcheron                      /fr/mmorpg/encyclopedie/metiers/2-bucheron
# Chasseur                     /fr/mmorpg/encyclopedie/metiers/41-chasseur
# Cordomage                   /fr/mmorpg/encyclopedie/metiers/62-cordomage
# Cordonnier                 /fr/mmorpg/encyclopedie/metiers/15-cordonnier
# Costumage                   /fr/mmorpg/encyclopedie/metiers/64-costumage
# Façonneur                   /fr/mmorpg/encyclopedie/metiers/60-faconneur
# Forgemage d'Epées      /fr/mmorpg/encyclopedie/metiers/44-forgemage-e...
# Forgemage de Dagues    /fr/mmorpg/encyclopedie/metiers/43-forgemage-d...
# Forgemage de Haches    /fr/mmorpg/encyclopedie/metiers/47-forgemage-h...
# Forgemage de Marteaux  /fr/mmorpg/encyclopedie/metiers/45-forgemage-m...
# Forgemage de Pelles    /fr/mmorpg/encyclopedie/metiers/46-forgemage-p...
# Forgeur d'Epées         /fr/mmorpg/encyclopedie/metiers/11-forgeur-epees
# Forgeur de Dagues      /fr/mmorpg/encyclopedie/metiers/17-forgeur-dagues
# Forgeur de Haches      /fr/mmorpg/encyclopedie/metiers/31-forgeur-haches
# Forgeur de Marteaux    /fr/mmorpg/encyclopedie/metiers/14-forgeur-mar...
# Forgeur de Pelles      /fr/mmorpg/encyclopedie/metiers/20-forgeur-pelles
# Joaillomage               /fr/mmorpg/encyclopedie/metiers/63-joaillomage
# Mineur                         /fr/mmorpg/encyclopedie/metiers/24-mineur
# Paysan                         /fr/mmorpg/encyclopedie/metiers/28-paysan
#
#                                                                  recipes
# Alchimiste             [{'detail_url': '/fr/mmorpg/encyclopedie/objet...
# Bijoutier              [{'detail_url': '/fr/mmorpg/encyclopedie/objet...
# Boucher                [{'detail_url': '/fr/mmorpg/encyclopedie/objet...
# Boulanger              [{'detail_url': '/fr/mmorpg/encyclopedie/objet...
# Bricoleur              [{'detail_url': '/fr/mmorpg/encyclopedie/objet...
# Bûcheron                                                              []
# Chasseur               [{'detail_url': '/fr/mmorpg/encyclopedie/objet...
# Cordomage                                                             []
# Cordonnier             [{'detail_url': '/fr/mmorpg/encyclopedie/objet...
# Costumage                                                             []
# Façonneur              [{'detail_url': '/fr/mmorpg/encyclopedie/objet...
# Forgemage d'Epées                                                     []
# Forgemage de Dagues                                                   []
# Forgemage de Haches                                                   []
# Forgemage de Marteaux                                                 []
# Forgemage de Pelles                                                   []
# Forgeur d'Epées        [{'detail_url': '/fr/mmorpg/encyclopedie/objet...
# Forgeur de Dagues      [{'detail_url': '/fr/mmorpg/encyclopedie/objet...
# Forgeur de Haches      [{'detail_url': '/fr/mmorpg/encyclopedie/objet...
# Forgeur de Marteaux    [{'detail_url': '/fr/mmorpg/encyclopedie/objet...
# Forgeur de Pelles      [{'detail_url': '/fr/mmorpg/encyclopedie/objet...
# Joaillomage                                                           []
# Mineur                 [{'detail_url': '/fr/mmorpg/encyclopedie/objet...
# Paysan                 [{'detail_url': '/fr/mmorpg/encyclopedie/objet...

# %%
{"Age":12,
"Cha":9,
"de chasse":394,
"Fo":12,
"Ine":22,
"Ini":159,
"Prospe":1977,
"Ré Air":193,
"Ré Eau":19,
"Ré Feu":19,
"Ré Neutre":79,
"Ré Per air":166,
"Ré Per Eau":157,
"Ré Per Feu":932,
"Ré Per Neutre":498,
"Ré Per Terre":898,
"Ré Terre":390,
"Sa":16,
"Vi":45,
"Cri":99,
"Do":452,
"Do Air":374,
"Do Cri":792,
"Do Eau":189,
"Do Feu":203,
"Do Neutre":284,
"Do Pou":252,
"Do Terre":157,
"Rui":49,
"Invo":7556,
"Pa Age":88,
"Pa Cha":76,
"Pa Do Air":7575,
"Pa Do Cri":3631,
"Pa Do Eau":5749,
"Pa Do Feu":4967,
"Pa Do Neutre":896,
"Pa Do Pou":3902,
"Pa Do Terre":2723,
"Pa Fo":108,
"Pa Fui":184,
"Pa Ine":121,
"Pa Ini":2160,
"Pa Prospe":8889,
"Pa Ré Cri":15956,
"Pa Ré Pa":26939,
"Pa Ré Pme":12077,
"Pa Ré Pou":4563,
"Pa Ret Pa":2267,
"Pa Ret Pme":833,
"Pa Sa":180,
"Pa Tac":1116,
"Pa Vi":777,
"Po":9911,
"Pod":28,
"Pui":96,
"Ré Cri":1404,
"Ré Pa":14894,
"Ré Pme":2304,
"Ré Pou":1962,
"Ret Pa":842,
"Ret Pme":202,
"So":188,
"Tac":144,
"Pa Pod":224,
"Pa Pui":1007,
"Ra Age":669,
"Ra Cha":625,
"Ra Fo":958,
"Ra Ine":1104,
"Ra Ini":8810,
"Ra Pod":1190,
"Ra Pui":7415,
"Ra Sa":823,
"Ra Vi":8552,
"Pa Ré Air":240,
"Pa Ré Eau":185,
"Pa Ré Feu":142,
"Pa Ré Neutre":1742,
"Pa Ré Terre":3200,
"Ga Pa":106910,
"Ga Pme":104554,
"Pa So":400}
# Out:
# {'Age': 12,
#  'Cha': 9,
#  'de chasse': 394,
#  'Fo': 12,
#  'Ine': 22,
#  'Ini': 159,
#  'Prospe': 1977,
#  'Ré Air': 193,
#  'Ré Eau': 19,
#  'Ré Feu': 19,
#  'Ré Neutre': 79,
#  'Ré Per air': 166,
#  'Ré Per Eau': 157,
#  'Ré Per Feu': 932,
#  'Ré Per Neutre': 498,
#  'Ré Per Terre': 898,
#  'Ré Terre': 390,
#  'Sa': 16,
#  'Vi': 45,
#  'Cri': 99,
#  'Do': 452,
#  'Do Air': 374,
#  'Do Cri': 792,
#  'Do Eau': 189,
#  'Do Feu': 203,
#  'Do Neutre': 284,
#  'Do Pou': 252,
#  'Do Terre': 157,
#  'Rui': 49,
#  'Invo': 7556,
#  'Pa Age': 88,
#  'Pa Cha': 76,
#  'Pa Do Air': 7575,
#  'Pa Do Cri': 3631,
#  'Pa Do Eau': 5749,
#  'Pa Do Feu': 4967,
#  'Pa Do Neutre': 896,
#  'Pa Do Pou': 3902,
#  'Pa Do Terre': 2723,
#  'Pa Fo': 108,
#  'Pa Fui': 184,
#  'Pa Ine': 121,
#  'Pa Ini': 2160,
#  'Pa Prospe': 8889,
#  'Pa Ré Cri': 15956,
#  'Pa Ré Pa': 26939,
#  'Pa Ré Pme': 12077,
#  'Pa Ré Pou': 4563,
#  'Pa Ret Pa': 2267,
#  'Pa Ret Pme': 833,
#  'Pa Sa': 180,
#  'Pa Tac': 1116,
#  'Pa Vi': 777,
#  'Po': 9911,
#  'Pod': 28,
#  'Pui': 96,
#  'Ré Cri': 1404,
#  'Ré Pa': 14894,
#  'Ré Pme': 2304,
#  'Ré Pou': 1962,
#  'Ret Pa': 842,
#  'Ret Pme': 202,
#  'So': 188,
#  'Tac': 144,
#  'Pa Pod': 224,
#  'Pa Pui': 1007,
#  'Ra Age': 669,
#  'Ra Cha': 625,
#  'Ra Fo': 958,
#  'Ra Ine': 1104,
#  'Ra Ini': 8810,
#  'Ra Pod': 1190,
#  'Ra Pui': 7415,
#  'Ra Sa': 823,
#  'Ra Vi': 8552,
#  'Pa Ré Air': 240,
#  'Pa Ré Eau': 185,
#  'Pa Ré Feu': 142,
#  'Pa Ré Neutre': 1742,
#  'Pa Ré Terre': 3200,
#  'Ga Pa': 106910,
#  'Ga Pme': 104554,
#  'Pa So': 400}

# %%
items
# Out:
# [<div class="ak-list-element">
#  <div class="ak-front">
#      1 x  </div>
#  <div class="ak-main">
#  <div class="ak-main-content">
#  <div class="ak-image">
#  <a href="/fr/mmorpg/encyclopedie/ressources/11499-frostiz-souffle">
#  <span class="ak-linker"><img height="48" src="https://static.ankama.com/dofus-touch/www/img/../../../dofus-touch/www/game/items/52/34553.w48h48.png" width="48"/></span><script type="application/json">{"iShowDelay":500,"iHideDelay":250,"linker-id":"linker_item_11499","linker-path":"\/fr\/linker\/item","linker-display-type":"TOOLTIP","linker-query-datas":{"l":"fr","id":"11499"}}</script> </a>
#  </div>
#  <div class="ak-content">
#  <div class="ak-title">
#  <a href="/fr/mmorpg/encyclopedie/ressources/11499-frostiz-souffle">
#  <span class="ak-linker">Frostiz soufflé</span><script type="application/json">{"iShowDelay":500,"iHideDelay":250,"linker-id":"linker_item_11499","linker-path":"\/fr\/linker\/item","linker-display-type":"TOOLTIP","linker-query-datas":{"l":"fr","id":"11499"}}</script> </a>
#  </div>
#  <div class="ak-text">Céréale</div>
#  </div>
#  <div class="ak-aside">Niv. 100</div>
#  </div>
#  </div>
#  </div>]

# %%
effects = items["effects"].explode()
effects = effects.dropna().drop_duplicates()
effect_names = pd.DataFrame(list(effects))["name"]
list(effect_names)
# Out:
# ['vi',
#  'fo',
#  'ag',
#  'ch',
#  'sa',
#  'daf',
#  'dtf',
#  'dnf',
#  'def',
#  'rtp',
#  'cc',
#  'po',
#  'pa',
#  'ii',
#  'vi',
#  'fo',
#  'rc',
#  'sa',
#  'ta',
#  'dtf',
#  'rep',
#  'rfp',
#  'cc',
#  'pa',
#  'vi',
#  'ag',
#  'sa',
#  'ta',
#  'daf',
#  'rtp',
#  'rep',
#  'dc',
#  'cc',
#  'po',
#  'pa',
#  'pm',
#  'vi',
#  'in',
#  'rp',
#  'sa',
#  'fu',
#  'dff',
#  'rnp',
#  'rep',
#  'cc',
#  'po',
#  'pa',
#  'vi',
#  'ag',
#  'sa',
#  'pp',
#  'fu',
#  'daf',
#  'dp',
#  'rtp',
#  'cc',
#  'pa',
#  'vi',
#  'pu',
#  'rp',
#  'rc',
#  'cc',
#  'pa',
#  'sa',
#  'vi',
#  'in',
#  'ch',
#  'rp',
#  'sa',
#  'fu',
#  'dff',
#  'def',
#  'rtp',
#  'rap',
#  'rpm',
#  'ic',
#  'pm',
#  'vi',
#  'pu',
#  'rep',
#  'rfp',
#  'pm',
#  'sa',
#  'vi',
#  'pu',
#  'rc',
#  'sa',
#  'pp',
#  'rtp',
#  'rep',
#  'epa',
#  'cc',
#  'pm',
#  'pa',
#  'vi',
#  'fo',
#  'ag',
#  'sa',
#  'ta',
#  'daf',
#  'dtf',
#  'rfp',
#  'po',
#  'pm',
#  'pa',
#  'vi',
#  'fo',
#  'rc',
#  'sa',
#  'dtf',
#  'ta',
#  'rep',
#  'rfp',
#  'epm',
#  'ic',
#  'pm',
#  'sp',
#  'vi',
#  'ta',
#  'epm',
#  'rt',
#  're',
#  'vi',
#  'in',
#  'ag',
#  'ch',
#  'sa',
#  'dff',
#  'daf',
#  'def',
#  'po',
#  'so',
#  'fu',
#  'rpa',
#  'rnp',
#  'rtp',
#  'rn',
#  'rt',
#  'rf',
#  'vi',
#  'in',
#  'ag',
#  'ch',
#  'sa',
#  'dff',
#  'daf',
#  'def',
#  'rpa',
#  'fu',
#  'pp',
#  'rtp',
#  'rfp',
#  'rt',
#  'rf',
#  'vi',
#  'in',
#  'ag',
#  'ch',
#  'sa',
#  'pa',
#  'ic',
#  'dff',
#  'daf',
#  'def',
#  'rpa',
#  'epm',
#  'rfp',
#  'vi',
#  'fo',
#  'sa',
#  'pa',
#  'po',
#  'dnf',
#  'dtf',
#  'pp',
#  'ii',
#  'fu',
#  'rpm',
#  'epa',
#  'rnp',
#  'rap',
#  'vi',
#  'fo',
#  'sa',
#  'pm',
#  'dnf',
#  'dtf',
#  'ii',
#  'fu',
#  'rpm',
#  'epa',
#  'rtp',
#  'rap',
#  'rn',
#  'rt',
#  'vi',
#  'fo',
#  'po',
#  'ic',
#  'dnf',
#  'dtf',
#  'ii',
#  'rpm',
#  'epa',
#  'rtp',
#  'rap',
#  'vi',
#  'in',
#  'ch',
#  'sa',
#  'cc',
#  'pa',
#  'po',
#  'dff',
#  'def',
#  'rnp',
#  'rtp',
#  'vi',
#  'in',
#  'ch',
#  'sa',
#  'cc',
#  'po',
#  'dff',
#  'def',
#  'so',
#  'dp',
#  'rfp',
#  'vi',
#  'in',
#  'ch',
#  'sa',
#  'pm',
#  'po',
#  'dff',
#  'def',
#  'dp',
#  'rnp',
#  'rtp',
#  'vi',
#  'fo',
#  'in',
#  'ag',
#  'sa',
#  'ta',
#  'dff',
#  'daf',
#  'dtf',
#  'dnf',
#  'rtp',
#  'cc',
#  'po',
#  'sp',
#  'ii',
#  'rc',
#  'rt',
#  'ra',
#  'vi',
#  'fo',
#  'in',
#  'ag',
#  'sa',
#  'dff',
#  'daf',
#  'dtf',
#  'dnf',
#  'rnp',
#  'cc',
#  'rfp',
#  'epa',
#  'vi',
#  'fo',
#  'in',
#  'ag',
#  'sa',
#  'dff',
#  'daf',
#  'dtf',
#  'dnf',
#  'rep',
#  'cc',
#  'rap',
#  'epa',
#  'po',
#  'vi',
#  'pu',
#  'sa',
#  'dff',
#  'daf',
#  'def',
#  'fu',
#  'dtf',
#  'rep',
#  'po',
#  'dc',
#  'cc',
#  'vi',
#  'pu',
#  'sa',
#  'fu',
#  'dff',
#  'daf',
#  'def',
#  'dtf',
#  'rep',
#  'rap',
#  'dc',
#  'cc',
#  'pm',
#  'vi',
#  'pu',
#  'sa',
#  'fu',
#  'dff',
#  'daf',
#  'def',
#  'dtf',
#  'rfp',
#  'rap',
#  'dc',
#  'rtp',
#  'vi',
#  'pu',
#  'rp',
#  'sa',
#  'rnp',
#  'rep',
#  'epm',
#  'dc',
#  'cc',
#  'pa',
#  'pp',
#  'fu',
#  'vi',
#  'in',
#  'ag',
#  'sa',
#  'dff',
#  'daf',
#  'ta',
#  'dc',
#  'dp',
#  'rtp',
#  'pa',
#  'pm',
#  'vi',
#  'pu',
#  'rp',
#  'rc',
#  'sa',
#  'pp',
#  'fu',
#  'rep',
#  'rfp',
#  'epa',
#  'epm',
#  'pa',
#  'vi',
#  'in',
#  'ag',
#  're',
#  'sa',
#  'dff',
#  'daf',
#  'rp',
#  'rep',
#  'so',
#  'cc',
#  'pa',
#  'rf',
#  'rfp',
#  'ii',
#  'vi',
#  'in',
#  'ag',
#  'ta',
#  'rf',
#  'rt',
#  'sa',
#  'fu',
#  'dff',
#  'daf',
#  'rtp',
#  'rfp',
#  'cc',
#  'po',
#  'pm',
#  'so',
#  'ii',
#  'vi',
#  'in',
#  'ag',
#  'rn',
#  'rt',
#  'sa',
#  'ta',
#  'fu',
#  'dff',
#  'daf',
#  'rtp',
#  'rnp',
#  'ic',
#  'cc',
#  'rp',
#  'rfp',
#  'vi',
#  'fo',
#  'ag',
#  'rc',
#  'sa',
#  'pp',
#  'dnf',
#  'daf',
#  'dtf',
#  'rtp',
#  'rep',
#  'dc',
#  'cc',
#  'pa',
#  'epa',
#  'vi',
#  'ag',
#  'fo',
#  'rp',
#  'sa',
#  'rt',
#  're',
#  'ra',
#  'rf',
#  'pp',
#  'daf',
#  'dtf',
#  'dnf',
#  'rap',
#  'ic',
#  'cc',
#  'pm',
#  'vi',
#  'ag',
#  'fo',
#  'rc',
#  'sa',
#  'pp',
#  'ta',
#  'daf',
#  'dtf',
#  'dnf',
#  'rap',
#  'rfp',
#  'epm',
#  'cc',
#  'ii',
#  'vi',
#  'pu',
#  'rp',
#  'rc',
#  'sa',
#  'rtp',
#  'rep',
#  'rap',
#  'rnp',
#  'rfp',
#  'dmg',
#  'pa',
#  'vi',
#  'fo',
#  'pu',
#  'rn',
#  'sa',
#  'ta',
#  'dtf',
#  'dnf',
#  'rnp',
#  'rep',
#  'epa',
#  'cc',
#  'ic',
#  'pa',
#  'vi',
#  'fo',
#  'ra',
#  'sa',
#  'ta',
#  'dnf',
#  'dtf',
#  'dp',
#  'rtp',
#  'rnp',
#  'rep',
#  'epa',
#  'cc',
#  'pp',
#  'vi',
#  'ii',
#  'pu',
#  'sa',
#  'pp',
#  'fu',
#  'dp',
#  'rfp',
#  'epm',
#  'cc',
#  'ic',
#  'dmg',
#  'vi',
#  'pu',
#  'sa',
#  'pp',
#  'dp',
#  'rep',
#  'epm',
#  'cc',
#  'po',
#  'pm',
#  'fu',
#  'rap',
#  'dmg',
#  'vi',
#  'sa',
#  'pp',
#  'fu',
#  'dp',
#  'rtp',
#  'rep',
#  'epa',
#  'pu',
#  'dmg',
#  'cc',
#  'sp',
#  'vi',
#  'rt',
#  're',
#  'ta',
#  'epm',
#  'vi',
#  'ag',
#  'sa',
#  'cc',
#  'po',
#  'pp',
#  'daf',
#  'rt',
#  'rep',
#  'dp',
#  'vi',
#  'sa',
#  'so',
#  'cc',
#  'pu',
#  'ii',
#  'dnf',
#  'dtf',
#  'dff',
#  'def',
#  'daf',
#  'rnp',
#  'ta',
#  'dc',
#  'rc',
#  'vi',
#  'in',
#  'ag',
#  'sa',
#  'cc',
#  'so',
#  'po',
#  'ii',
#  'dff',
#  'rap',
#  'fu',
#  'dc',
#  'vi',
#  'in',
#  'pu',
#  'sa',
#  'fu',
#  'dff',
#  'rnp',
#  'rap',
#  'pp',
#  'so',
#  'pm',
#  'epa',
#  'vi',
#  'ag',
#  'ch',
#  'sa',
#  'daf',
#  'def',
#  'rnp',
#  'ta',
#  'rc',
#  'pp',
#  'po',
#  'ii',
#  'rtp',
#  'vi',
#  'ag',
#  'rp',
#  'sa',
#  'pp',
#  'daf',
#  'rtp',
#  'epm',
#  'po',
#  'vi',
#  'fo',
#  'ch',
#  'ta',
#  'sa',
#  'def',
#  'dtf',
#  'dnf',
#  'rnp',
#  'rep',
#  'po',
#  'vi',
#  'fo',
#  'in',
#  'ch',
#  'epa',
#  'sa',
#  'dtf',
#  'dnf',
#  'def',
#  'rtp',
#  'dff',
#  'vi',
#  'fo',
#  'in',
#  'ag',
#  'ii',
#  'dnf',
#  'dtf',
#  'dff',
#  'daf',
#  'rep',
#  'ta',
#  'vi',
#  'in',
#  'ch',
#  'sa',
#  'so',
#  'po',
#  'dff',
#  'def',
#  'dc',
#  'vi',
#  'fo',
#  'sa',
#  'cc',
#  'ii',
#  'dnf',
#  'dtf',
#  'rc',
#  'vi',
#  'ch',
#  'sa',
#  'pp',
#  'def',
#  'rfp',
#  'rnp',
#  'rtp',
#  'epa',
#  'cc',
#  'pm',
#  'vi',
#  'ii',
#  'fo',
#  'ag',
#  'sa',
#  'fu',
#  'daf',
#  'dtf',
#  'dnf',
#  'rep',
#  'rfp',
#  'cc',
#  'pm',
#  'ii',
#  'vi',
#  'in',
#  'sa',
#  'pp',
#  'fu',
#  'dff',
#  'rtp',
#  'rap',
#  'epa',
#  'so',
#  'cc',
#  'pm',
#  'vi',
#  'in',
#  'ch',
#  'ag',
#  'sa',
#  'cc',
#  'pm',
#  'dff',
#  'def',
#  'daf',
#  'ic',
#  'rnp',
#  'pp',
#  'vi',
#  'in',
#  'ch',
#  'rc',
#  'sa',
#  'dff',
#  'def',
#  'rnp',
#  'rfp',
#  'so',
#  'cc',
#  'pm',
#  'vi',
#  'ag',
#  'ch',
#  'sa',
#  'daf',
#  'def',
#  'rc',
#  'rtp',
#  'rep',
#  'fu',
#  'pm',
#  'ic',
#  'pp',
#  'vi',
#  'in',
#  'fo',
#  'sa',
#  'dff',
#  'dtf',
#  'dnf',
#  'fu',
#  'pm',
#  'rp',
#  'rt',
#  're',
#  'rfp',
#  'rep',
#  'pa',
#  'vi',
#  'fo',
#  'ch',
#  'sa',
#  'pp',
#  'def',
#  'dtf',
#  'dnf',
#  'rfp',
#  'epm',
#  'cc',
#  'rap',
#  'po',
#  'pm',
#  'vi',
#  'fo',
#  'in',
#  'ch',
#  'epa',
#  'sa',
#  'pp',
#  'dff',
#  'dtf',
#  'dnf',
#  'rap',
#  'pm',
#  'def',
#  'vi',
#  'ch',
#  'sa',
#  'pm',
#  'po',
#  'ii',
#  'pp',
#  'def',
#  'ra',
#  'rtp',
#  'dc',
#  'vi',
#  'sa',
#  'pu',
#  'pm',
#  'dnf',
#  'dtf',
#  'dff',
#  'def',
#  'daf',
#  'rfp',
#  'epa',
#  'rc',
#  'vi',
#  'fo',
#  'in',
#  'ag',
#  'sa',
#  'cc',
#  'pm',
#  'po',
#  'dnf',
#  'dtf',
#  'dff',
#  'daf',
#  'rt',
#  'rap',
#  'dp',
#  'dc',
#  'vi',
#  'ch',
#  'sa',
#  'pm',
#  'ii',
#  'pp',
#  'dtf',
#  'def',
#  'rn',
#  're',
#  'rtp',
#  'rap',
#  'vi',
#  'fo',
#  'sa',
#  'pm',
#  'dnf',
#  'dtf',
#  'rn',
#  'epm',
#  'ta',
#  'rp',
#  'vi',
#  'fo',
#  'ag',
#  'sa',
#  'fu',
#  'daf',
#  'dtf',
#  'dnf',
#  'rep',
#  'rap',
#  'ii',
#  'pa',
#  'vi',
#  'fo',
#  'in',
#  'sa',
#  'dtf',
#  'dnf',
#  'dff',
#  'fu',
#  'pp',
#  'pa',
#  'po',
#  'epa',
#  'rep',
#  'vi',
#  'fo',
#  'in',
#  'rp',
#  'rc',
#  're',
#  'ra',
#  'rf',
#  'sa',
#  'rpm',
#  'dff',
#  'dtf',
#  'dnf',
#  'po',
#  'pa',
#  'vi',
#  'ag',
#  'rp',
#  'sa',
#  'pp',
#  'daf',
#  'rep',
#  'rfp',
#  'epm',
#  'cc',
#  'po',
#  'pa',
#  'vi',
#  'fo',
#  'sa',
#  'cc',
#  'pa',
#  'pp',
#  'dtf',
#  're',
#  'rap',
#  'dc',
#  'vi',
#  'sa',
#  'cc',
#  'pu',
#  'pa',
#  'rtp',
#  'rap',
#  'epa',
#  'ta',
#  'dc',
#  'rc',
#  'vi',
#  'fo',
#  'in',
#  'ag',
#  'sa',
#  'pa',
#  'ic',
#  'dnf',
#  'dtf',
#  'dff',
#  'daf',
#  'rnp',
#  'rfp',
#  'epa',
#  'ta',
#  'vi',
#  'in',
#  'ch',
#  'sa',
#  'cc',
#  'pa',
#  'ii',
#  'pp',
#  'dff',
#  'def',
#  'rtp',
#  'rap',
#  'ta',
#  'vi',
#  'ch',
#  'sa',
#  'cc',
#  'pa',
#  'po',
#  'pp',
#  'dtf',
#  'def',
#  'ra',
#  'rfp',
#  'epm',
#  'dp',
#  'rc',
#  'vi',
#  'ag',
#  'sa',
#  'cc',
#  'pa',
#  'po',
#  'ic',
#  'pp',
#  'daf',
#  're',
#  'ra',
#  'ta',
#  'dc',
#  'vi',
#  'in',
#  'ag',
#  'sa',
#  'pa',
#  'pp',
#  'dff',
#  'daf',
#  'rnp',
#  'rfp',
#  'rc',
#  'vi',
#  'ch',
#  'pu',
#  'rp',
#  'sa',
#  'pp',
#  'def',
#  'rtp',
#  'rnp',
#  'rfp',
#  'cc',
#  'vi',
#  'fo',
#  'in',
#  'sa',
#  'dff',
#  'dtf',
#  'dnf',
#  'rfp',
#  'rap',
#  'cc',
#  'fu',
#  'ic',
#  'vi',
#  'in',
#  'ch',
#  'ag',
#  'sa',
#  ...]

# %%
ingredients = items["ingredients"].explode()
ingredients = ingredients.dropna()
ingredients = pd.DataFrame(list(ingredients)).set_index("id")
ingredients = ingredients.drop(columns=["count", "picture", "item_id"])
ingredients = ingredients.drop_duplicates()
ingredients.to_json("ingredients.json")
ingredients
# Out:
#                              name
# id
# 11883   Condyle de Fuji Givrefoux
# 11939       Incisive de Glourmand
# 13062                Galet acajou
# 13994  Scapula du Comte Harebourg
# 15748                  Orbe irisé
# ...                           ...
# 285                 Farine de Blé
# 694                 Dofus Pourpre
# 737                Dofus Émeraude
# 739               Dofus Turquoise
# 1019                       Casque
#
# [1095 rows x 1 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
